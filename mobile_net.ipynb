# %% [markdown]
# # 🍽️ Food Image Classifier + Nutrition Lookup
# CNN (MobileNetV2 Transfer Learning) + CSV Nutrition Data

# %%
# !pip install tensorflow pandas numpy matplotlib -q
import tensorflow as tf, pandas as pd, numpy as np, matplotlib.pyplot as plt
print('TF:', tf.__version__)
# Out:
# TF: 2.20.0

# %% [markdown]
# ## 1. Extract Dataset

# %%
import zipfile
with zipfile.ZipFile('dataset (6).zip', 'r') as z:
    z.extractall('dataset')
print('Done.')
# Out:
# Done.

# %% [markdown]
# ## 2. Load Nutrition CSV & Build Lookup
#
# The CSV (`final_matched_dataset.csv`) maps dish names → `matched_name` (which matches our image class folders). We build a lookup table: **class_name → avg nutrition per 100g**.

# %%
import pandas as pd

df = pd.read_csv('final_matched_dataset (1).csv')   # upload this CSV to Colab
print('CSV shape:', df.shape)
print(df.head(3))

# Normalize matched_name to match image folder names (spaces → underscores, lowercase)
df['class_key'] = df['matched_name'].str.lower().str.strip().str.replace(' ', '_')

# Manual aliases for classes not directly in matched_name
ALIASES = {
    'bakery':        'bread',        # closest match
    'bread':         'rye bread',
    'breakfast':     'breakfast sausage links',
    'burger':        'hamburger',
    'cake':          'yellow cake',
    'cheese':        'cream cheese',
    'chips':         'baked chips',
    'chocolate':     'chocolate bar',
    'coffee':        'coffee creamer',
    'fish':          'white fish',
    'fried_chicken': 'chicken',
    'grape':         'grapes',
    'ice_cream':     'ice cream cake',
    'juice':         'orange juice',
    'lettuce':       'romaine lettuce',
    'milk':          'oat milk',
    'noodles':       'egg noodles cooked',
    'pizza':         'margherita pizza',
    'popcorn':       'popcorn air popped',
    'potato':        'white potato',
    'rice':          'spanish rice',
    'salad':         'greek salad',
    'shawarma':      'kebab',        # closest available
    'smoothie':      'fruit smoothie',
    'strawberry':    'strawberry',
    'sushi':         'tuna sushi maki',
    'watermelon':    'watermelon',
    'yogurt':        'greek yogurt',
}

# Build mean nutrition per class_key
nutrition_by_key = (
    df.groupby('class_key')[['calories','protein','fat','carb']]
      .mean().round(2)
      .to_dict(orient='index')
)

def get_nutrition(class_name):
    """Return nutrition dict for a given image class name."""
    key = class_name.lower().replace(' ', '_')
    if key in nutrition_by_key:
        return nutrition_by_key[key]
    # Try alias
    alias_key = ALIASES.get(key, '').lower().replace(' ', '_')
    if alias_key and alias_key in nutrition_by_key:
        return nutrition_by_key[alias_key]
    # Partial match fallback
    for k in nutrition_by_key:
        if key in k or k in key:
            return nutrition_by_key[k]
    return {'calories': None, 'protein': None, 'fat': None, 'carb': None}

# Quick test
for test_class in ['chicken', 'pizza', 'sushi', 'apple']:
    print(f'{test_class:15s} → {get_nutrition(test_class)}')
# Out:
# CSV shape: (13829, 9)
#              name matched_name  \
# 0   chicken handi      chicken
# 1   chicken mandi      chicken
# 2  sticky chicken      chicken
#
#                                          ingredients category portion  \
# 0  Chicken, Onion, Tomatoes, Garlic, Ginger paste...     meat   100 g
# 1  Chicken, Basmati Rice, Water, Onion, Garlic, G...     meat   100 g
# 2  Chicken drumsticks, Soy Sauce, Honey, Olive Oi...     meat   100 g
#
#    calories  protein   fat  carb
# 0     166.0     21.4  1.79   0.0
# 1     166.0     21.4  1.79   0.0
# 2     166.0     21.4  1.79   0.0
# chicken         → {'calories': 166.0, 'protein': 21.4, 'fat': 1.79, 'carb': 0.0}
# pizza           → {'calories': 240.0, 'protein': 10.6, 'fat': 9.41, 'carb': 24.7}
# sushi           → {'calories': 173.0, 'protein': 5.66, 'fat': 3.77, 'carb': 10.4}
# apple           → {'calories': 64.0, 'protein': 0.0, 'fat': 0.0, 'carb': 11.7}

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'dataset', 'dataset (6).zip', 'final_matched_dataset (1).csv', 'sample_data']

# %%
# !ls -R dataset
# Out:
# dataset:
# dataset
#
# dataset/dataset:
# apple	   carrot     falafel	     lettuce	potato	    sushi
# bakery	   cheese     fish	     mango	quinoa	    sweet_potato
# banana	   chicken    fried_chicken  milk	rice	    taco
# beef	   chips      garlic	     noodles	salad	    tea
# bread	   chocolate  grape	     oats	salmon	    tomato
# breakfast  coffee     hummus	     onion	sandwich    tuna
# broccoli   cookies    ice_cream      orange	shawarma    turkey
# burger	   corn       juice	     pasta	shrimp	    watermelon
# burrito    cream      kebab	     pineapple	smoothie    yogurt
# butter	   cucumber   lamb	     pizza	spinach
# cake	   duck       lasagna	     popcorn	strawberry
#
# dataset/dataset/apple:
# apple_0.jpg    apple_154.jpg  apple_208.jpg  apple_262.jpg  apple_46.jpg
# apple_100.jpg  apple_155.jpg  apple_209.jpg  apple_263.jpg  apple_47.jpg
# apple_101.jpg  apple_156.jpg  apple_20.jpg   apple_264.jpg  apple_48.jpg
# apple_102.jpg  apple_157.jpg  apple_210.jpg  apple_265.jpg  apple_49.jpg
# apple_103.jpg  apple_158.jpg  apple_211.jpg  apple_266.jpg  apple_4.jpg
# apple_104.jpg  apple_159.jpg  apple_212.jpg  apple_267.jpg  apple_50.jpg
# apple_105.jpg  apple_15.jpg   apple_213.jpg  apple_268.jpg  apple_51.jpg
# apple_106.jpg  apple_160.jpg  apple_214.jpg  apple_269.jpg  apple_52.jpg
# apple_107.jpg  apple_161.jpg  apple_215.jpg  apple_26.jpg   apple_53.jpg
# apple_108.jpg  apple_162.jpg  apple_216.jpg  apple_270.jpg  apple_54.jpg
# apple_109.jpg  apple_163.jpg  apple_217.jpg  apple_271.jpg  apple_55.jpg
# apple_10.jpg   apple_164.jpg  apple_218.jpg  apple_272.jpg  apple_56.jpg
# apple_110.jpg  apple_165.jpg  apple_219.jpg  apple_273.jpg  apple_57.jpg
# apple_111.jpg  apple_166.jpg  apple_21.jpg   apple_274.jpg  apple_58.jpg
# apple_112.jpg  apple_167.jpg  apple_220.jpg  apple_275.jpg  apple_59.jpg
# apple_113.jpg  apple_168.jpg  apple_221.jpg  apple_276.jpg  apple_5.jpg
# apple_114.jpg  apple_169.jpg  apple_222.jpg  apple_277.jpg  apple_60.jpg
# apple_115.jpg  apple_16.jpg   apple_223.jpg  apple_278.jpg  apple_61.jpg
# apple_116.jpg  apple_170.jpg  apple_224.jpg  apple_279.jpg  apple_62.jpg
# apple_117.jpg  apple_171.jpg  apple_225.jpg  apple_27.jpg   apple_63.jpg
# apple_118.jpg  apple_172.jpg  apple_226.jpg  apple_280.jpg  apple_64.jpg
# apple_119.jpg  apple_173.jpg  apple_227.jpg  apple_281.jpg  apple_65.jpg
# apple_11.jpg   apple_174.jpg  apple_228.jpg  apple_282.jpg  apple_66.jpg
# apple_120.jpg  apple_175.jpg  apple_229.jpg  apple_283.jpg  apple_67.jpg
# apple_121.jpg  apple_176.jpg  apple_22.jpg   apple_284.jpg  apple_68.jpg
# apple_122.jpg  apple_177.jpg  apple_230.jpg  apple_285.jpg  apple_69.jpg
# apple_123.jpg  apple_178.jpg  apple_231.jpg  apple_286.jpg  apple_6.jpg
# apple_124.jpg  apple_179.jpg  apple_232.jpg  apple_287.jpg  apple_70.jpg
# apple_125.jpg  apple_17.jpg   apple_233.jpg  apple_288.jpg  apple_71.jpg
# apple_126.jpg  apple_180.jpg  apple_234.jpg  apple_289.jpg  apple_72.jpg
# apple_127.jpg  apple_181.jpg  apple_235.jpg  apple_28.jpg   apple_73.jpg
# apple_128.jpg  apple_182.jpg  apple_236.jpg  apple_290.jpg  apple_74.jpg
# apple_129.jpg  apple_183.jpg  apple_237.jpg  apple_291.jpg  apple_75.jpg
# apple_12.jpg   apple_184.jpg  apple_238.jpg  apple_292.jpg  apple_76.jpg
# apple_130.jpg  apple_185.jpg  apple_239.jpg  apple_293.jpg  apple_77.jpg
# apple_131.jpg  apple_186.jpg  apple_23.jpg   apple_294.jpg  apple_78.jpg
# apple_132.jpg  apple_187.jpg  apple_240.jpg  apple_295.jpg  apple_79.jpg
# apple_133.jpg  apple_188.jpg  apple_241.jpg  apple_296.jpg  apple_7.jpg
# apple_134.jpg  apple_189.jpg  apple_242.jpg  apple_297.jpg  apple_80.jpg
# apple_135.jpg  apple_18.jpg   apple_243.jpg  apple_298.jpg  apple_81.jpg
# apple_136.jpg  apple_190.jpg  apple_244.jpg  apple_299.jpg  apple_82.jpg
# apple_137.jpg  apple_191.jpg  apple_245.jpg  apple_29.jpg   apple_83.jpg
# apple_138.jpg  apple_192.jpg  apple_246.jpg  apple_2.jpg    apple_84.jpg
# apple_139.jpg  apple_193.jpg  apple_247.jpg  apple_30.jpg   apple_85.jpg
# apple_13.jpg   apple_194.jpg  apple_248.jpg  apple_31.jpg   apple_86.jpg
# apple_140.jpg  apple_195.jpg  apple_249.jpg  apple_32.jpg   apple_87.jpg
# apple_141.jpg  apple_196.jpg  apple_24.jpg   apple_33.jpg   apple_88.jpg
# apple_142.jpg  apple_197.jpg  apple_250.jpg  apple_34.jpg   apple_89.jpg
# apple_143.jpg  apple_198.jpg  apple_251.jpg  apple_35.jpg   apple_8.jpg
# apple_144.jpg  apple_199.jpg  apple_252.jpg  apple_36.jpg   apple_90.jpg
# apple_145.jpg  apple_19.jpg   apple_253.jpg  apple_37.jpg   apple_91.jpg
# apple_146.jpg  apple_1.jpg    apple_254.jpg  apple_38.jpg   apple_92.jpg
# apple_147.jpg  apple_200.jpg  apple_255.jpg  apple_39.jpg   apple_93.jpg
# apple_148.jpg  apple_201.jpg  apple_256.jpg  apple_3.jpg    apple_94.jpg
# apple_149.jpg  apple_202.jpg  apple_257.jpg  apple_40.jpg   apple_95.jpg
# apple_14.jpg   apple_203.jpg  apple_258.jpg  apple_41.jpg   apple_96.jpg
# apple_150.jpg  apple_204.jpg  apple_259.jpg  apple_42.jpg   apple_97.jpg
# apple_151.jpg  apple_205.jpg  apple_25.jpg   apple_43.jpg   apple_98.jpg
# apple_152.jpg  apple_206.jpg  apple_260.jpg  apple_44.jpg   apple_99.jpg
# apple_153.jpg  apple_207.jpg  apple_261.jpg  apple_45.jpg   apple_9.jpg
#
# dataset/dataset/bakery:
# bakery_0.jpg   bakery_15.jpg  bakery_20.jpg  bakery_26.jpg  bakery_4.jpg
# bakery_10.jpg  bakery_16.jpg  bakery_21.jpg  bakery_27.jpg  bakery_5.jpg
# bakery_11.jpg  bakery_17.jpg  bakery_22.jpg  bakery_28.jpg  bakery_6.jpg
# bakery_12.jpg  bakery_18.jpg  bakery_23.jpg  bakery_29.jpg  bakery_7.jpg
# bakery_13.jpg  bakery_19.jpg  bakery_24.jpg  bakery_2.jpg   bakery_8.jpg
# bakery_14.jpg  bakery_1.jpg   bakery_25.jpg  bakery_3.jpg   bakery_9.jpg
#
# dataset/dataset/banana:
# banana_0.jpg	banana_154.jpg	banana_208.jpg	banana_262.jpg	banana_46.jpg
# banana_100.jpg	banana_155.jpg	banana_209.jpg	banana_263.jpg	banana_47.jpg
# banana_101.jpg	banana_156.jpg	banana_20.jpg	banana_264.jpg	banana_48.jpg
# banana_102.jpg	banana_157.jpg	banana_210.jpg	banana_265.jpg	banana_49.jpg
# banana_103.jpg	banana_158.jpg	banana_211.jpg	banana_266.jpg	banana_4.jpg
# banana_104.jpg	banana_159.jpg	banana_212.jpg	banana_267.jpg	banana_50.jpg
# banana_105.jpg	banana_15.jpg	banana_213.jpg	banana_268.jpg	banana_51.jpg
# banana_106.jpg	banana_160.jpg	banana_214.jpg	banana_269.jpg	banana_52.jpg
# banana_107.jpg	banana_161.jpg	banana_215.jpg	banana_26.jpg	banana_53.jpg
# banana_108.jpg	banana_162.jpg	banana_216.jpg	banana_270.jpg	banana_54.jpg
# banana_109.jpg	banana_163.jpg	banana_217.jpg	banana_271.jpg	banana_55.jpg
# banana_10.jpg	banana_164.jpg	banana_218.jpg	banana_272.jpg	banana_56.jpg
# banana_110.jpg	banana_165.jpg	banana_219.jpg	banana_273.jpg	banana_57.jpg
# banana_111.jpg	banana_166.jpg	banana_21.jpg	banana_274.jpg	banana_58.jpg
# banana_112.jpg	banana_167.jpg	banana_220.jpg	banana_275.jpg	banana_59.jpg
# banana_113.jpg	banana_168.jpg	banana_221.jpg	banana_276.jpg	banana_5.jpg
# banana_114.jpg	banana_169.jpg	banana_222.jpg	banana_277.jpg	banana_60.jpg
# banana_115.jpg	banana_16.jpg	banana_223.jpg	banana_278.jpg	banana_61.jpg
# banana_116.jpg	banana_170.jpg	banana_224.jpg	banana_279.jpg	banana_62.jpg
# banana_117.jpg	banana_171.jpg	banana_225.jpg	banana_27.jpg	banana_63.jpg
# banana_118.jpg	banana_172.jpg	banana_226.jpg	banana_280.jpg	banana_64.jpg
# banana_119.jpg	banana_173.jpg	banana_227.jpg	banana_281.jpg	banana_65.jpg
# banana_11.jpg	banana_174.jpg	banana_228.jpg	banana_282.jpg	banana_66.jpg
# banana_120.jpg	banana_175.jpg	banana_229.jpg	banana_283.jpg	banana_67.jpg
# banana_121.jpg	banana_176.jpg	banana_22.jpg	banana_284.jpg	banana_68.jpg
# banana_122.jpg	banana_177.jpg	banana_230.jpg	banana_285.jpg	banana_69.jpg
# banana_123.jpg	banana_178.jpg	banana_231.jpg	banana_286.jpg	banana_6.jpg
# banana_124.jpg	banana_179.jpg	banana_232.jpg	banana_287.jpg	banana_70.jpg
# banana_125.jpg	banana_17.jpg	banana_233.jpg	banana_288.jpg	banana_71.jpg
# banana_126.jpg	banana_180.jpg	banana_234.jpg	banana_289.jpg	banana_72.jpg
# banana_127.jpg	banana_181.jpg	banana_235.jpg	banana_28.jpg	banana_73.jpg
# banana_128.jpg	banana_182.jpg	banana_236.jpg	banana_290.jpg	banana_74.jpg
# banana_129.jpg	banana_183.jpg	banana_237.jpg	banana_291.jpg	banana_75.jpg
# banana_12.jpg	banana_184.jpg	banana_238.jpg	banana_292.jpg	banana_76.jpg
# banana_130.jpg	banana_185.jpg	banana_239.jpg	banana_293.jpg	banana_77.jpg
# banana_131.jpg	banana_186.jpg	banana_23.jpg	banana_294.jpg	banana_78.jpg
# banana_132.jpg	banana_187.jpg	banana_240.jpg	banana_295.jpg	banana_79.jpg
# banana_133.jpg	banana_188.jpg	banana_241.jpg	banana_296.jpg	banana_7.jpg
# banana_134.jpg	banana_189.jpg	banana_242.jpg	banana_297.jpg	banana_80.jpg
# banana_135.jpg	banana_18.jpg	banana_243.jpg	banana_298.jpg	banana_81.jpg
# banana_136.jpg	banana_190.jpg	banana_244.jpg	banana_299.jpg	banana_82.jpg
# banana_137.jpg	banana_191.jpg	banana_245.jpg	banana_29.jpg	banana_83.jpg
# banana_138.jpg	banana_192.jpg	banana_246.jpg	banana_2.jpg	banana_84.jpg
# banana_139.jpg	banana_193.jpg	banana_247.jpg	banana_30.jpg	banana_85.jpg
# banana_13.jpg	banana_194.jpg	banana_248.jpg	banana_31.jpg	banana_86.jpg
# banana_140.jpg	banana_195.jpg	banana_249.jpg	banana_32.jpg	banana_87.jpg
# banana_141.jpg	banana_196.jpg	banana_24.jpg	banana_33.jpg	banana_88.jpg
# banana_142.jpg	banana_197.jpg	banana_250.jpg	banana_34.jpg	banana_89.jpg
# banana_143.jpg	banana_198.jpg	banana_251.jpg	banana_35.jpg	banana_8.jpg
# banana_144.jpg	banana_199.jpg	banana_252.jpg	banana_36.jpg	banana_90.jpg
# banana_145.jpg	banana_19.jpg	banana_253.jpg	banana_37.jpg	banana_91.jpg
# banana_146.jpg	banana_1.jpg	banana_254.jpg	banana_38.jpg	banana_92.jpg
# banana_147.jpg	banana_200.jpg	banana_255.jpg	banana_39.jpg	banana_93.jpg
# banana_148.jpg	banana_201.jpg	banana_256.jpg	banana_3.jpg	banana_94.jpg
# banana_149.jpg	banana_202.jpg	banana_257.jpg	banana_40.jpg	banana_95.jpg
# banana_14.jpg	banana_203.jpg	banana_258.jpg	banana_41.jpg	banana_96.jpg
# banana_150.jpg	banana_204.jpg	banana_259.jpg	banana_42.jpg	banana_97.jpg
# banana_151.jpg	banana_205.jpg	banana_25.jpg	banana_43.jpg	banana_98.jpg
# banana_152.jpg	banana_206.jpg	banana_260.jpg	banana_44.jpg	banana_99.jpg
# banana_153.jpg	banana_207.jpg	banana_261.jpg	banana_45.jpg	banana_9.jpg
#
# dataset/dataset/beef:
# beef_0.jpg    beef_154.jpg  beef_208.jpg  beef_262.jpg	beef_46.jpg
# beef_100.jpg  beef_155.jpg  beef_209.jpg  beef_263.jpg	beef_47.jpg
# beef_101.jpg  beef_156.jpg  beef_20.jpg   beef_264.jpg	beef_48.jpg
# beef_102.jpg  beef_157.jpg  beef_210.jpg  beef_265.jpg	beef_49.jpg
# beef_103.jpg  beef_158.jpg  beef_211.jpg  beef_266.jpg	beef_4.jpg
# beef_104.jpg  beef_159.jpg  beef_212.jpg  beef_267.jpg	beef_50.jpg
# beef_105.jpg  beef_15.jpg   beef_213.jpg  beef_268.jpg	beef_51.jpg
# beef_106.jpg  beef_160.jpg  beef_214.jpg  beef_269.jpg	beef_52.jpg
# beef_107.jpg  beef_161.jpg  beef_215.jpg  beef_26.jpg	beef_53.jpg
# beef_108.jpg  beef_162.jpg  beef_216.jpg  beef_270.jpg	beef_54.jpg
# beef_109.jpg  beef_163.jpg  beef_217.jpg  beef_271.jpg	beef_55.jpg
# beef_10.jpg   beef_164.jpg  beef_218.jpg  beef_272.jpg	beef_56.jpg
# beef_110.jpg  beef_165.jpg  beef_219.jpg  beef_273.jpg	beef_57.jpg
# beef_111.jpg  beef_166.jpg  beef_21.jpg   beef_274.jpg	beef_58.jpg
# beef_112.jpg  beef_167.jpg  beef_220.jpg  beef_275.jpg	beef_59.jpg
# beef_113.jpg  beef_168.jpg  beef_221.jpg  beef_276.jpg	beef_5.jpg
# beef_114.jpg  beef_169.jpg  beef_222.jpg  beef_277.jpg	beef_60.jpg
# beef_115.jpg  beef_16.jpg   beef_223.jpg  beef_278.jpg	beef_61.jpg
# beef_116.jpg  beef_170.jpg  beef_224.jpg  beef_279.jpg	beef_62.jpg
# beef_117.jpg  beef_171.jpg  beef_225.jpg  beef_27.jpg	beef_63.jpg
# beef_118.jpg  beef_172.jpg  beef_226.jpg  beef_280.jpg	beef_64.jpg
# beef_119.jpg  beef_173.jpg  beef_227.jpg  beef_281.jpg	beef_65.jpg
# beef_11.jpg   beef_174.jpg  beef_228.jpg  beef_282.jpg	beef_66.jpg
# beef_120.jpg  beef_175.jpg  beef_229.jpg  beef_283.jpg	beef_67.jpg
# beef_121.jpg  beef_176.jpg  beef_22.jpg   beef_284.jpg	beef_68.jpg
# beef_122.jpg  beef_177.jpg  beef_230.jpg  beef_285.jpg	beef_69.jpg
# beef_123.jpg  beef_178.jpg  beef_231.jpg  beef_286.jpg	beef_6.jpg
# beef_124.jpg  beef_179.jpg  beef_232.jpg  beef_287.jpg	beef_70.jpg
# beef_125.jpg  beef_17.jpg   beef_233.jpg  beef_288.jpg	beef_71.jpg
# beef_126.jpg  beef_180.jpg  beef_234.jpg  beef_289.jpg	beef_72.jpg
# beef_127.jpg  beef_181.jpg  beef_235.jpg  beef_28.jpg	beef_73.jpg
# beef_128.jpg  beef_182.jpg  beef_236.jpg  beef_290.jpg	beef_74.jpg
# beef_129.jpg  beef_183.jpg  beef_237.jpg  beef_291.jpg	beef_75.jpg
# beef_12.jpg   beef_184.jpg  beef_238.jpg  beef_292.jpg	beef_76.jpg
# beef_130.jpg  beef_185.jpg  beef_239.jpg  beef_293.jpg	beef_77.jpg
# beef_131.jpg  beef_186.jpg  beef_23.jpg   beef_294.jpg	beef_78.jpg
# beef_132.jpg  beef_187.jpg  beef_240.jpg  beef_295.jpg	beef_79.jpg
# beef_133.jpg  beef_188.jpg  beef_241.jpg  beef_296.jpg	beef_7.jpg
# beef_134.jpg  beef_189.jpg  beef_242.jpg  beef_297.jpg	beef_80.jpg
# beef_135.jpg  beef_18.jpg   beef_243.jpg  beef_298.jpg	beef_81.jpg
# beef_136.jpg  beef_190.jpg  beef_244.jpg  beef_299.jpg	beef_82.jpg
# beef_137.jpg  beef_191.jpg  beef_245.jpg  beef_29.jpg	beef_83.jpg
# beef_138.jpg  beef_192.jpg  beef_246.jpg  beef_2.jpg	beef_84.jpg
# beef_139.jpg  beef_193.jpg  beef_247.jpg  beef_30.jpg	beef_85.jpg
# beef_13.jpg   beef_194.jpg  beef_248.jpg  beef_31.jpg	beef_86.jpg
# beef_140.jpg  beef_195.jpg  beef_249.jpg  beef_32.jpg	beef_87.jpg
# beef_141.jpg  beef_196.jpg  beef_24.jpg   beef_33.jpg	beef_88.jpg
# beef_142.jpg  beef_197.jpg  beef_250.jpg  beef_34.jpg	beef_89.jpg
# beef_143.jpg  beef_198.jpg  beef_251.jpg  beef_35.jpg	beef_8.jpg
# beef_144.jpg  beef_199.jpg  beef_252.jpg  beef_36.jpg	beef_90.jpg
# beef_145.jpg  beef_19.jpg   beef_253.jpg  beef_37.jpg	beef_91.jpg
# beef_146.jpg  beef_1.jpg    beef_254.jpg  beef_38.jpg	beef_92.jpg
# beef_147.jpg  beef_200.jpg  beef_255.jpg  beef_39.jpg	beef_93.jpg
# beef_148.jpg  beef_201.jpg  beef_256.jpg  beef_3.jpg	beef_94.jpg
# beef_149.jpg  beef_202.jpg  beef_257.jpg  beef_40.jpg	beef_95.jpg
# beef_14.jpg   beef_203.jpg  beef_258.jpg  beef_41.jpg	beef_96.jpg
# beef_150.jpg  beef_204.jpg  beef_259.jpg  beef_42.jpg	beef_97.jpg
# beef_151.jpg  beef_205.jpg  beef_25.jpg   beef_43.jpg	beef_98.jpg
# beef_152.jpg  beef_206.jpg  beef_260.jpg  beef_44.jpg	beef_99.jpg
# beef_153.jpg  beef_207.jpg  beef_261.jpg  beef_45.jpg	beef_9.jpg
#
# dataset/dataset/bread:
# bread_0.jpg    bread_154.jpg  bread_208.jpg  bread_262.jpg  bread_46.jpg
# bread_100.jpg  bread_155.jpg  bread_209.jpg  bread_263.jpg  bread_47.jpg
# bread_101.jpg  bread_156.jpg  bread_20.jpg   bread_264.jpg  bread_48.jpg
# bread_102.jpg  bread_157.jpg  bread_210.jpg  bread_265.jpg  bread_49.jpg
# bread_103.jpg  bread_158.jpg  bread_211.jpg  bread_266.jpg  bread_4.jpg
# bread_104.jpg  bread_159.jpg  bread_212.jpg  bread_267.jpg  bread_50.jpg
# bread_105.jpg  bread_15.jpg   bread_213.jpg  bread_268.jpg  bread_51.jpg
# bread_106.jpg  bread_160.jpg  bread_214.jpg  bread_269.jpg  bread_52.jpg
# bread_107.jpg  bread_161.jpg  bread_215.jpg  bread_26.jpg   bread_53.jpg
# bread_108.jpg  bread_162.jpg  bread_216.jpg  bread_270.jpg  bread_54.jpg
# bread_109.jpg  bread_163.jpg  bread_217.jpg  bread_271.jpg  bread_55.jpg
# bread_10.jpg   bread_164.jpg  bread_218.jpg  bread_272.jpg  bread_56.jpg
# bread_110.jpg  bread_165.jpg  bread_219.jpg  bread_273.jpg  bread_57.jpg
# bread_111.jpg  bread_166.jpg  bread_21.jpg   bread_274.jpg  bread_58.jpg
# bread_112.jpg  bread_167.jpg  bread_220.jpg  bread_275.jpg  bread_59.jpg
# bread_113.jpg  bread_168.jpg  bread_221.jpg  bread_276.jpg  bread_5.jpg
# bread_114.jpg  bread_169.jpg  bread_222.jpg  bread_277.jpg  bread_60.jpg
# bread_115.jpg  bread_16.jpg   bread_223.jpg  bread_278.jpg  bread_61.jpg
# bread_116.jpg  bread_170.jpg  bread_224.jpg  bread_279.jpg  bread_62.jpg
# bread_117.jpg  bread_171.jpg  bread_225.jpg  bread_27.jpg   bread_63.jpg
# bread_118.jpg  bread_172.jpg  bread_226.jpg  bread_280.jpg  bread_64.jpg
# bread_119.jpg  bread_173.jpg  bread_227.jpg  bread_281.jpg  bread_65.jpg
# bread_11.jpg   bread_174.jpg  bread_228.jpg  bread_282.jpg  bread_66.jpg
# bread_120.jpg  bread_175.jpg  bread_229.jpg  bread_283.jpg  bread_67.jpg
# bread_121.jpg  bread_176.jpg  bread_22.jpg   bread_284.jpg  bread_68.jpg
# bread_122.jpg  bread_177.jpg  bread_230.jpg  bread_285.jpg  bread_69.jpg
# bread_123.jpg  bread_178.jpg  bread_231.jpg  bread_286.jpg  bread_6.jpg
# bread_124.jpg  bread_179.jpg  bread_232.jpg  bread_287.jpg  bread_70.jpg
# bread_125.jpg  bread_17.jpg   bread_233.jpg  bread_288.jpg  bread_71.jpg
# bread_126.jpg  bread_180.jpg  bread_234.jpg  bread_289.jpg  bread_72.jpg
# bread_127.jpg  bread_181.jpg  bread_235.jpg  bread_28.jpg   bread_73.jpg
# bread_128.jpg  bread_182.jpg  bread_236.jpg  bread_290.jpg  bread_74.jpg
# bread_129.jpg  bread_183.jpg  bread_237.jpg  bread_291.jpg  bread_75.jpg
# bread_12.jpg   bread_184.jpg  bread_238.jpg  bread_292.jpg  bread_76.jpg
# bread_130.jpg  bread_185.jpg  bread_239.jpg  bread_293.jpg  bread_77.jpg
# bread_131.jpg  bread_186.jpg  bread_23.jpg   bread_294.jpg  bread_78.jpg
# bread_132.jpg  bread_187.jpg  bread_240.jpg  bread_295.jpg  bread_79.jpg
# bread_133.jpg  bread_188.jpg  bread_241.jpg  bread_296.jpg  bread_7.jpg
# bread_134.jpg  bread_189.jpg  bread_242.jpg  bread_297.jpg  bread_80.jpg
# bread_135.jpg  bread_18.jpg   bread_243.jpg  bread_298.jpg  bread_81.jpg
# bread_136.jpg  bread_190.jpg  bread_244.jpg  bread_299.jpg  bread_82.jpg
# bread_137.jpg  bread_191.jpg  bread_245.jpg  bread_29.jpg   bread_83.jpg
# bread_138.jpg  bread_192.jpg  bread_246.jpg  bread_2.jpg    bread_84.jpg
# bread_139.jpg  bread_193.jpg  bread_247.jpg  bread_30.jpg   bread_85.jpg
# bread_13.jpg   bread_194.jpg  bread_248.jpg  bread_31.jpg   bread_86.jpg
# bread_140.jpg  bread_195.jpg  bread_249.jpg  bread_32.jpg   bread_87.jpg
# bread_141.jpg  bread_196.jpg  bread_24.jpg   bread_33.jpg   bread_88.jpg
# bread_142.jpg  bread_197.jpg  bread_250.jpg  bread_34.jpg   bread_89.jpg
# bread_143.jpg  bread_198.jpg  bread_251.jpg  bread_35.jpg   bread_8.jpg
# bread_144.jpg  bread_199.jpg  bread_252.jpg  bread_36.jpg   bread_90.jpg
# bread_145.jpg  bread_19.jpg   bread_253.jpg  bread_37.jpg   bread_91.jpg
# bread_146.jpg  bread_1.jpg    bread_254.jpg  bread_38.jpg   bread_92.jpg
# bread_147.jpg  bread_200.jpg  bread_255.jpg  bread_39.jpg   bread_93.jpg
# bread_148.jpg  bread_201.jpg  bread_256.jpg  bread_3.jpg    bread_94.jpg
# bread_149.jpg  bread_202.jpg  bread_257.jpg  bread_40.jpg   bread_95.jpg
# bread_14.jpg   bread_203.jpg  bread_258.jpg  bread_41.jpg   bread_96.jpg
# bread_150.jpg  bread_204.jpg  bread_259.jpg  bread_42.jpg   bread_97.jpg
# bread_151.jpg  bread_205.jpg  bread_25.jpg   bread_43.jpg   bread_98.jpg
# bread_152.jpg  bread_206.jpg  bread_260.jpg  bread_44.jpg   bread_99.jpg
# bread_153.jpg  bread_207.jpg  bread_261.jpg  bread_45.jpg   bread_9.jpg
#
# dataset/dataset/breakfast:
# breakfast_0.jpg   breakfast_17.jpg  breakfast_24.jpg  breakfast_4.jpg
# breakfast_10.jpg  breakfast_18.jpg  breakfast_25.jpg  breakfast_5.jpg
# breakfast_11.jpg  breakfast_19.jpg  breakfast_26.jpg  breakfast_6.jpg
# breakfast_12.jpg  breakfast_1.jpg   breakfast_27.jpg  breakfast_7.jpg
# breakfast_13.jpg  breakfast_20.jpg  breakfast_28.jpg  breakfast_8.jpg
# breakfast_14.jpg  breakfast_21.jpg  breakfast_29.jpg  breakfast_9.jpg
# breakfast_15.jpg  breakfast_22.jpg  breakfast_2.jpg
# breakfast_16.jpg  breakfast_23.jpg  breakfast_3.jpg
#
# dataset/dataset/broccoli:
# broccoli_0.jpg	  broccoli_168.jpg  broccoli_235.jpg  broccoli_32.jpg
# broccoli_100.jpg  broccoli_169.jpg  broccoli_236.jpg  broccoli_33.jpg
# broccoli_101.jpg  broccoli_16.jpg   broccoli_237.jpg  broccoli_34.jpg
# broccoli_102.jpg  broccoli_170.jpg  broccoli_238.jpg  broccoli_35.jpg
# broccoli_103.jpg  broccoli_171.jpg  broccoli_239.jpg  broccoli_36.jpg
# broccoli_104.jpg  broccoli_172.jpg  broccoli_23.jpg   broccoli_37.jpg
# broccoli_105.jpg  broccoli_173.jpg  broccoli_240.jpg  broccoli_38.jpg
# broccoli_106.jpg  broccoli_174.jpg  broccoli_241.jpg  broccoli_39.jpg
# broccoli_107.jpg  broccoli_175.jpg  broccoli_242.jpg  broccoli_3.jpg
# broccoli_108.jpg  broccoli_176.jpg  broccoli_243.jpg  broccoli_40.jpg
# broccoli_109.jpg  broccoli_177.jpg  broccoli_244.jpg  broccoli_41.jpg
# broccoli_10.jpg   broccoli_178.jpg  broccoli_245.jpg  broccoli_42.jpg
# broccoli_110.jpg  broccoli_179.jpg  broccoli_246.jpg  broccoli_43.jpg
# broccoli_111.jpg  broccoli_17.jpg   broccoli_247.jpg  broccoli_44.jpg
# broccoli_112.jpg  broccoli_180.jpg  broccoli_248.jpg  broccoli_45.jpg
# broccoli_113.jpg  broccoli_181.jpg  broccoli_249.jpg  broccoli_46.jpg
# broccoli_114.jpg  broccoli_182.jpg  broccoli_24.jpg   broccoli_47.jpg
# broccoli_115.jpg  broccoli_183.jpg  broccoli_250.jpg  broccoli_48.jpg
# broccoli_116.jpg  broccoli_184.jpg  broccoli_251.jpg  broccoli_49.jpg
# broccoli_117.jpg  broccoli_185.jpg  broccoli_252.jpg  broccoli_4.jpg
# broccoli_118.jpg  broccoli_186.jpg  broccoli_253.jpg  broccoli_50.jpg
# broccoli_119.jpg  broccoli_187.jpg  broccoli_254.jpg  broccoli_51.jpg
# broccoli_11.jpg   broccoli_188.jpg  broccoli_255.jpg  broccoli_52.jpg
# broccoli_120.jpg  broccoli_189.jpg  broccoli_256.jpg  broccoli_53.jpg
# broccoli_121.jpg  broccoli_18.jpg   broccoli_257.jpg  broccoli_54.jpg
# broccoli_122.jpg  broccoli_190.jpg  broccoli_258.jpg  broccoli_55.jpg
# broccoli_123.jpg  broccoli_191.jpg  broccoli_259.jpg  broccoli_56.jpg
# broccoli_124.jpg  broccoli_192.jpg  broccoli_25.jpg   broccoli_57.jpg
# broccoli_125.jpg  broccoli_193.jpg  broccoli_260.jpg  broccoli_58.jpg
# broccoli_126.jpg  broccoli_194.jpg  broccoli_261.jpg  broccoli_59.jpg
# broccoli_127.jpg  broccoli_195.jpg  broccoli_262.jpg  broccoli_5.jpg
# broccoli_128.jpg  broccoli_196.jpg  broccoli_263.jpg  broccoli_60.jpg
# broccoli_129.jpg  broccoli_197.jpg  broccoli_264.jpg  broccoli_61.jpg
# broccoli_12.jpg   broccoli_198.jpg  broccoli_265.jpg  broccoli_62.jpg
# broccoli_130.jpg  broccoli_199.jpg  broccoli_266.jpg  broccoli_63.jpg
# broccoli_131.jpg  broccoli_19.jpg   broccoli_267.jpg  broccoli_64.jpg
# broccoli_132.jpg  broccoli_1.jpg    broccoli_268.jpg  broccoli_65.jpg
# broccoli_133.jpg  broccoli_200.jpg  broccoli_269.jpg  broccoli_66.jpg
# broccoli_134.jpg  broccoli_201.jpg  broccoli_26.jpg   broccoli_67.jpg
# broccoli_135.jpg  broccoli_202.jpg  broccoli_270.jpg  broccoli_68.jpg
# broccoli_136.jpg  broccoli_203.jpg  broccoli_271.jpg  broccoli_69.jpg
# broccoli_137.jpg  broccoli_204.jpg  broccoli_272.jpg  broccoli_6.jpg
# broccoli_138.jpg  broccoli_205.jpg  broccoli_273.jpg  broccoli_70.jpg
# broccoli_139.jpg  broccoli_206.jpg  broccoli_274.jpg  broccoli_71.jpg
# broccoli_13.jpg   broccoli_207.jpg  broccoli_275.jpg  broccoli_72.jpg
# broccoli_140.jpg  broccoli_208.jpg  broccoli_276.jpg  broccoli_73.jpg
# broccoli_141.jpg  broccoli_209.jpg  broccoli_277.jpg  broccoli_74.jpg
# broccoli_142.jpg  broccoli_20.jpg   broccoli_278.jpg  broccoli_75.jpg
# broccoli_143.jpg  broccoli_210.jpg  broccoli_279.jpg  broccoli_76.jpg
# broccoli_144.jpg  broccoli_211.jpg  broccoli_27.jpg   broccoli_77.jpg
# broccoli_145.jpg  broccoli_212.jpg  broccoli_280.jpg  broccoli_78.jpg
# broccoli_146.jpg  broccoli_213.jpg  broccoli_281.jpg  broccoli_79.jpg
# broccoli_147.jpg  broccoli_214.jpg  broccoli_282.jpg  broccoli_7.jpg
# broccoli_148.jpg  broccoli_215.jpg  broccoli_283.jpg  broccoli_80.jpg
# broccoli_149.jpg  broccoli_216.jpg  broccoli_284.jpg  broccoli_81.jpg
# broccoli_14.jpg   broccoli_217.jpg  broccoli_285.jpg  broccoli_82.jpg
# broccoli_150.jpg  broccoli_218.jpg  broccoli_286.jpg  broccoli_83.jpg
# broccoli_151.jpg  broccoli_219.jpg  broccoli_287.jpg  broccoli_84.jpg
# broccoli_152.jpg  broccoli_21.jpg   broccoli_288.jpg  broccoli_85.jpg
# broccoli_153.jpg  broccoli_220.jpg  broccoli_289.jpg  broccoli_86.jpg
# broccoli_154.jpg  broccoli_221.jpg  broccoli_28.jpg   broccoli_87.jpg
# broccoli_155.jpg  broccoli_222.jpg  broccoli_290.jpg  broccoli_88.jpg
# broccoli_156.jpg  broccoli_223.jpg  broccoli_291.jpg  broccoli_89.jpg
# broccoli_157.jpg  broccoli_224.jpg  broccoli_292.jpg  broccoli_8.jpg
# broccoli_158.jpg  broccoli_225.jpg  broccoli_293.jpg  broccoli_90.jpg
# broccoli_159.jpg  broccoli_226.jpg  broccoli_294.jpg  broccoli_91.jpg
# broccoli_15.jpg   broccoli_227.jpg  broccoli_295.jpg  broccoli_92.jpg
# broccoli_160.jpg  broccoli_228.jpg  broccoli_296.jpg  broccoli_93.jpg
# broccoli_161.jpg  broccoli_229.jpg  broccoli_297.jpg  broccoli_94.jpg
# broccoli_162.jpg  broccoli_22.jpg   broccoli_298.jpg  broccoli_95.jpg
# broccoli_163.jpg  broccoli_230.jpg  broccoli_299.jpg  broccoli_96.jpg
# broccoli_164.jpg  broccoli_231.jpg  broccoli_29.jpg   broccoli_97.jpg
# broccoli_165.jpg  broccoli_232.jpg  broccoli_2.jpg    broccoli_98.jpg
# broccoli_166.jpg  broccoli_233.jpg  broccoli_30.jpg   broccoli_99.jpg
# broccoli_167.jpg  broccoli_234.jpg  broccoli_31.jpg   broccoli_9.jpg
#
# dataset/dataset/burger:
# burger_0.jpg	burger_154.jpg	burger_208.jpg	burger_262.jpg	burger_46.jpg
# burger_100.jpg	burger_155.jpg	burger_209.jpg	burger_263.jpg	burger_47.jpg
# burger_101.jpg	burger_156.jpg	burger_20.jpg	burger_264.jpg	burger_48.jpg
# burger_102.jpg	burger_157.jpg	burger_210.jpg	burger_265.jpg	burger_49.jpg
# burger_103.jpg	burger_158.jpg	burger_211.jpg	burger_266.jpg	burger_4.jpg
# burger_104.jpg	burger_159.jpg	burger_212.jpg	burger_267.jpg	burger_50.jpg
# burger_105.jpg	burger_15.jpg	burger_213.jpg	burger_268.jpg	burger_51.jpg
# burger_106.jpg	burger_160.jpg	burger_214.jpg	burger_269.jpg	burger_52.jpg
# burger_107.jpg	burger_161.jpg	burger_215.jpg	burger_26.jpg	burger_53.jpg
# burger_108.jpg	burger_162.jpg	burger_216.jpg	burger_270.jpg	burger_54.jpg
# burger_109.jpg	burger_163.jpg	burger_217.jpg	burger_271.jpg	burger_55.jpg
# burger_10.jpg	burger_164.jpg	burger_218.jpg	burger_272.jpg	burger_56.jpg
# burger_110.jpg	burger_165.jpg	burger_219.jpg	burger_273.jpg	burger_57.jpg
# burger_111.jpg	burger_166.jpg	burger_21.jpg	burger_274.jpg	burger_58.jpg
# burger_112.jpg	burger_167.jpg	burger_220.jpg	burger_275.jpg	burger_59.jpg
# burger_113.jpg	burger_168.jpg	burger_221.jpg	burger_276.jpg	burger_5.jpg
# burger_114.jpg	burger_169.jpg	burger_222.jpg	burger_277.jpg	burger_60.jpg
# burger_115.jpg	burger_16.jpg	burger_223.jpg	burger_278.jpg	burger_61.jpg
# burger_116.jpg	burger_170.jpg	burger_224.jpg	burger_279.jpg	burger_62.jpg
# burger_117.jpg	burger_171.jpg	burger_225.jpg	burger_27.jpg	burger_63.jpg
# burger_118.jpg	burger_172.jpg	burger_226.jpg	burger_280.jpg	burger_64.jpg
# burger_119.jpg	burger_173.jpg	burger_227.jpg	burger_281.jpg	burger_65.jpg
# burger_11.jpg	burger_174.jpg	burger_228.jpg	burger_282.jpg	burger_66.jpg
# burger_120.jpg	burger_175.jpg	burger_229.jpg	burger_283.jpg	burger_67.jpg
# burger_121.jpg	burger_176.jpg	burger_22.jpg	burger_284.jpg	burger_68.jpg
# burger_122.jpg	burger_177.jpg	burger_230.jpg	burger_285.jpg	burger_69.jpg
# burger_123.jpg	burger_178.jpg	burger_231.jpg	burger_286.jpg	burger_6.jpg
# burger_124.jpg	burger_179.jpg	burger_232.jpg	burger_287.jpg	burger_70.jpg
# burger_125.jpg	burger_17.jpg	burger_233.jpg	burger_288.jpg	burger_71.jpg
# burger_126.jpg	burger_180.jpg	burger_234.jpg	burger_289.jpg	burger_72.jpg
# burger_127.jpg	burger_181.jpg	burger_235.jpg	burger_28.jpg	burger_73.jpg
# burger_128.jpg	burger_182.jpg	burger_236.jpg	burger_290.jpg	burger_74.jpg
# burger_129.jpg	burger_183.jpg	burger_237.jpg	burger_291.jpg	burger_75.jpg
# burger_12.jpg	burger_184.jpg	burger_238.jpg	burger_292.jpg	burger_76.jpg
# burger_130.jpg	burger_185.jpg	burger_239.jpg	burger_293.jpg	burger_77.jpg
# burger_131.jpg	burger_186.jpg	burger_23.jpg	burger_294.jpg	burger_78.jpg
# burger_132.jpg	burger_187.jpg	burger_240.jpg	burger_295.jpg	burger_79.jpg
# burger_133.jpg	burger_188.jpg	burger_241.jpg	burger_296.jpg	burger_7.jpg
# burger_134.jpg	burger_189.jpg	burger_242.jpg	burger_297.jpg	burger_80.jpg
# burger_135.jpg	burger_18.jpg	burger_243.jpg	burger_298.jpg	burger_81.jpg
# burger_136.jpg	burger_190.jpg	burger_244.jpg	burger_299.jpg	burger_82.jpg
# burger_137.jpg	burger_191.jpg	burger_245.jpg	burger_29.jpg	burger_83.jpg
# burger_138.jpg	burger_192.jpg	burger_246.jpg	burger_2.jpg	burger_84.jpg
# burger_139.jpg	burger_193.jpg	burger_247.jpg	burger_30.jpg	burger_85.jpg
# burger_13.jpg	burger_194.jpg	burger_248.jpg	burger_31.jpg	burger_86.jpg
# burger_140.jpg	burger_195.jpg	burger_249.jpg	burger_32.jpg	burger_87.jpg
# burger_141.jpg	burger_196.jpg	burger_24.jpg	burger_33.jpg	burger_88.jpg
# burger_142.jpg	burger_197.jpg	burger_250.jpg	burger_34.jpg	burger_89.jpg
# burger_143.jpg	burger_198.jpg	burger_251.jpg	burger_35.jpg	burger_8.jpg
# burger_144.jpg	burger_199.jpg	burger_252.jpg	burger_36.jpg	burger_90.jpg
# burger_145.jpg	burger_19.jpg	burger_253.jpg	burger_37.jpg	burger_91.jpg
# burger_146.jpg	burger_1.jpg	burger_254.jpg	burger_38.jpg	burger_92.jpg
# burger_147.jpg	burger_200.jpg	burger_255.jpg	burger_39.jpg	burger_93.jpg
# burger_148.jpg	burger_201.jpg	burger_256.jpg	burger_3.jpg	burger_94.jpg
# burger_149.jpg	burger_202.jpg	burger_257.jpg	burger_40.jpg	burger_95.jpg
# burger_14.jpg	burger_203.jpg	burger_258.jpg	burger_41.jpg	burger_96.jpg
# burger_150.jpg	burger_204.jpg	burger_259.jpg	burger_42.jpg	burger_97.jpg
# burger_151.jpg	burger_205.jpg	burger_25.jpg	burger_43.jpg	burger_98.jpg
# burger_152.jpg	burger_206.jpg	burger_260.jpg	burger_44.jpg	burger_99.jpg
# burger_153.jpg	burger_207.jpg	burger_261.jpg	burger_45.jpg	burger_9.jpg
#
# dataset/dataset/burrito:
# burrito_0.jpg	 burrito_168.jpg  burrito_235.jpg  burrito_32.jpg
# burrito_100.jpg  burrito_169.jpg  burrito_236.jpg  burrito_33.jpg
# burrito_101.jpg  burrito_16.jpg   burrito_237.jpg  burrito_34.jpg
# burrito_102.jpg  burrito_170.jpg  burrito_238.jpg  burrito_35.jpg
# burrito_103.jpg  burrito_171.jpg  burrito_239.jpg  burrito_36.jpg
# burrito_104.jpg  burrito_172.jpg  burrito_23.jpg   burrito_37.jpg
# burrito_105.jpg  burrito_173.jpg  burrito_240.jpg  burrito_38.jpg
# burrito_106.jpg  burrito_174.jpg  burrito_241.jpg  burrito_39.jpg
# burrito_107.jpg  burrito_175.jpg  burrito_242.jpg  burrito_3.jpg
# burrito_108.jpg  burrito_176.jpg  burrito_243.jpg  burrito_40.jpg
# burrito_109.jpg  burrito_177.jpg  burrito_244.jpg  burrito_41.jpg
# burrito_10.jpg	 burrito_178.jpg  burrito_245.jpg  burrito_42.jpg
# burrito_110.jpg  burrito_179.jpg  burrito_246.jpg  burrito_43.jpg
# burrito_111.jpg  burrito_17.jpg   burrito_247.jpg  burrito_44.jpg
# burrito_112.jpg  burrito_180.jpg  burrito_248.jpg  burrito_45.jpg
# burrito_113.jpg  burrito_181.jpg  burrito_249.jpg  burrito_46.jpg
# burrito_114.jpg  burrito_182.jpg  burrito_24.jpg   burrito_47.jpg
# burrito_115.jpg  burrito_183.jpg  burrito_250.jpg  burrito_48.jpg
# burrito_116.jpg  burrito_184.jpg  burrito_251.jpg  burrito_49.jpg
# burrito_117.jpg  burrito_185.jpg  burrito_252.jpg  burrito_4.jpg
# burrito_118.jpg  burrito_186.jpg  burrito_253.jpg  burrito_50.jpg
# burrito_119.jpg  burrito_187.jpg  burrito_254.jpg  burrito_51.jpg
# burrito_11.jpg	 burrito_188.jpg  burrito_255.jpg  burrito_52.jpg
# burrito_120.jpg  burrito_189.jpg  burrito_256.jpg  burrito_53.jpg
# burrito_121.jpg  burrito_18.jpg   burrito_257.jpg  burrito_54.jpg
# burrito_122.jpg  burrito_190.jpg  burrito_258.jpg  burrito_55.jpg
# burrito_123.jpg  burrito_191.jpg  burrito_259.jpg  burrito_56.jpg
# burrito_124.jpg  burrito_192.jpg  burrito_25.jpg   burrito_57.jpg
# burrito_125.jpg  burrito_193.jpg  burrito_260.jpg  burrito_58.jpg
# burrito_126.jpg  burrito_194.jpg  burrito_261.jpg  burrito_59.jpg
# burrito_127.jpg  burrito_195.jpg  burrito_262.jpg  burrito_5.jpg
# burrito_128.jpg  burrito_196.jpg  burrito_263.jpg  burrito_60.jpg
# burrito_129.jpg  burrito_197.jpg  burrito_264.jpg  burrito_61.jpg
# burrito_12.jpg	 burrito_198.jpg  burrito_265.jpg  burrito_62.jpg
# burrito_130.jpg  burrito_199.jpg  burrito_266.jpg  burrito_63.jpg
# burrito_131.jpg  burrito_19.jpg   burrito_267.jpg  burrito_64.jpg
# burrito_132.jpg  burrito_1.jpg	  burrito_268.jpg  burrito_65.jpg
# burrito_133.jpg  burrito_200.jpg  burrito_269.jpg  burrito_66.jpg
# burrito_134.jpg  burrito_201.jpg  burrito_26.jpg   burrito_67.jpg
# burrito_135.jpg  burrito_202.jpg  burrito_270.jpg  burrito_68.jpg
# burrito_136.jpg  burrito_203.jpg  burrito_271.jpg  burrito_69.jpg
# burrito_137.jpg  burrito_204.jpg  burrito_272.jpg  burrito_6.jpg
# burrito_138.jpg  burrito_205.jpg  burrito_273.jpg  burrito_70.jpg
# burrito_139.jpg  burrito_206.jpg  burrito_274.jpg  burrito_71.jpg
# burrito_13.jpg	 burrito_207.jpg  burrito_275.jpg  burrito_72.jpg
# burrito_140.jpg  burrito_208.jpg  burrito_276.jpg  burrito_73.jpg
# burrito_141.jpg  burrito_209.jpg  burrito_277.jpg  burrito_74.jpg
# burrito_142.jpg  burrito_20.jpg   burrito_278.jpg  burrito_75.jpg
# burrito_143.jpg  burrito_210.jpg  burrito_279.jpg  burrito_76.jpg
# burrito_144.jpg  burrito_211.jpg  burrito_27.jpg   burrito_77.jpg
# burrito_145.jpg  burrito_212.jpg  burrito_280.jpg  burrito_78.jpg
# burrito_146.jpg  burrito_213.jpg  burrito_281.jpg  burrito_79.jpg
# burrito_147.jpg  burrito_214.jpg  burrito_282.jpg  burrito_7.jpg
# burrito_148.jpg  burrito_215.jpg  burrito_283.jpg  burrito_80.jpg
# burrito_149.jpg  burrito_216.jpg  burrito_284.jpg  burrito_81.jpg
# burrito_14.jpg	 burrito_217.jpg  burrito_285.jpg  burrito_82.jpg
# burrito_150.jpg  burrito_218.jpg  burrito_286.jpg  burrito_83.jpg
# burrito_151.jpg  burrito_219.jpg  burrito_287.jpg  burrito_84.jpg
# burrito_152.jpg  burrito_21.jpg   burrito_288.jpg  burrito_85.jpg
# burrito_153.jpg  burrito_220.jpg  burrito_289.jpg  burrito_86.jpg
# burrito_154.jpg  burrito_221.jpg  burrito_28.jpg   burrito_87.jpg
# burrito_155.jpg  burrito_222.jpg  burrito_290.jpg  burrito_88.jpg
# burrito_156.jpg  burrito_223.jpg  burrito_291.jpg  burrito_89.jpg
# burrito_157.jpg  burrito_224.jpg  burrito_292.jpg  burrito_8.jpg
# burrito_158.jpg  burrito_225.jpg  burrito_293.jpg  burrito_90.jpg
# burrito_159.jpg  burrito_226.jpg  burrito_294.jpg  burrito_91.jpg
# burrito_15.jpg	 burrito_227.jpg  burrito_295.jpg  burrito_92.jpg
# burrito_160.jpg  burrito_228.jpg  burrito_296.jpg  burrito_93.jpg
# burrito_161.jpg  burrito_229.jpg  burrito_297.jpg  burrito_94.jpg
# burrito_162.jpg  burrito_22.jpg   burrito_298.jpg  burrito_95.jpg
# burrito_163.jpg  burrito_230.jpg  burrito_299.jpg  burrito_96.jpg
# burrito_164.jpg  burrito_231.jpg  burrito_29.jpg   burrito_97.jpg
# burrito_165.jpg  burrito_232.jpg  burrito_2.jpg    burrito_98.jpg
# burrito_166.jpg  burrito_233.jpg  burrito_30.jpg   burrito_99.jpg
# burrito_167.jpg  burrito_234.jpg  burrito_31.jpg   burrito_9.jpg
#
# dataset/dataset/butter:
# butter_0.jpg	butter_154.jpg	butter_208.jpg	butter_262.jpg	butter_46.jpg
# butter_100.jpg	butter_155.jpg	butter_209.jpg	butter_263.jpg	butter_47.jpg
# butter_101.jpg	butter_156.jpg	butter_20.jpg	butter_264.jpg	butter_48.jpg
# butter_102.jpg	butter_157.jpg	butter_210.jpg	butter_265.jpg	butter_49.jpg
# butter_103.jpg	butter_158.jpg	butter_211.jpg	butter_266.jpg	butter_4.jpg
# butter_104.jpg	butter_159.jpg	butter_212.jpg	butter_267.jpg	butter_50.jpg
# butter_105.jpg	butter_15.jpg	butter_213.jpg	butter_268.jpg	butter_51.jpg
# butter_106.jpg	butter_160.jpg	butter_214.jpg	butter_269.jpg	butter_52.jpg
# butter_107.jpg	butter_161.jpg	butter_215.jpg	butter_26.jpg	butter_53.jpg
# butter_108.jpg	butter_162.jpg	butter_216.jpg	butter_270.jpg	butter_54.jpg
# butter_109.jpg	butter_163.jpg	butter_217.jpg	butter_271.jpg	butter_55.jpg
# butter_10.jpg	butter_164.jpg	butter_218.jpg	butter_272.jpg	butter_56.jpg
# butter_110.jpg	butter_165.jpg	butter_219.jpg	butter_273.jpg	butter_57.jpg
# butter_111.jpg	butter_166.jpg	butter_21.jpg	butter_274.jpg	butter_58.jpg
# butter_112.jpg	butter_167.jpg	butter_220.jpg	butter_275.jpg	butter_59.jpg
# butter_113.jpg	butter_168.jpg	butter_221.jpg	butter_276.jpg	butter_5.jpg
# butter_114.jpg	butter_169.jpg	butter_222.jpg	butter_277.jpg	butter_60.jpg
# butter_115.jpg	butter_16.jpg	butter_223.jpg	butter_278.jpg	butter_61.jpg
# butter_116.jpg	butter_170.jpg	butter_224.jpg	butter_279.jpg	butter_62.jpg
# butter_117.jpg	butter_171.jpg	butter_225.jpg	butter_27.jpg	butter_63.jpg
# butter_118.jpg	butter_172.jpg	butter_226.jpg	butter_280.jpg	butter_64.jpg
# butter_119.jpg	butter_173.jpg	butter_227.jpg	butter_281.jpg	butter_65.jpg
# butter_11.jpg	butter_174.jpg	butter_228.jpg	butter_282.jpg	butter_66.jpg
# butter_120.jpg	butter_175.jpg	butter_229.jpg	butter_283.jpg	butter_67.jpg
# butter_121.jpg	butter_176.jpg	butter_22.jpg	butter_284.jpg	butter_68.jpg
# butter_122.jpg	butter_177.jpg	butter_230.jpg	butter_285.jpg	butter_69.jpg
# butter_123.jpg	butter_178.jpg	butter_231.jpg	butter_286.jpg	butter_6.jpg
# butter_124.jpg	butter_179.jpg	butter_232.jpg	butter_287.jpg	butter_70.jpg
# butter_125.jpg	butter_17.jpg	butter_233.jpg	butter_288.jpg	butter_71.jpg
# butter_126.jpg	butter_180.jpg	butter_234.jpg	butter_289.jpg	butter_72.jpg
# butter_127.jpg	butter_181.jpg	butter_235.jpg	butter_28.jpg	butter_73.jpg
# butter_128.jpg	butter_182.jpg	butter_236.jpg	butter_290.jpg	butter_74.jpg
# butter_129.jpg	butter_183.jpg	butter_237.jpg	butter_291.jpg	butter_75.jpg
# butter_12.jpg	butter_184.jpg	butter_238.jpg	butter_292.jpg	butter_76.jpg
# butter_130.jpg	butter_185.jpg	butter_239.jpg	butter_293.jpg	butter_77.jpg
# butter_131.jpg	butter_186.jpg	butter_23.jpg	butter_294.jpg	butter_78.jpg
# butter_132.jpg	butter_187.jpg	butter_240.jpg	butter_295.jpg	butter_79.jpg
# butter_133.jpg	butter_188.jpg	butter_241.jpg	butter_296.jpg	butter_7.jpg
# butter_134.jpg	butter_189.jpg	butter_242.jpg	butter_297.jpg	butter_80.jpg
# butter_135.jpg	butter_18.jpg	butter_243.jpg	butter_298.jpg	butter_81.jpg
# butter_136.jpg	butter_190.jpg	butter_244.jpg	butter_299.jpg	butter_82.jpg
# butter_137.jpg	butter_191.jpg	butter_245.jpg	butter_29.jpg	butter_83.jpg
# butter_138.jpg	butter_192.jpg	butter_246.jpg	butter_2.jpg	butter_84.jpg
# butter_139.jpg	butter_193.jpg	butter_247.jpg	butter_30.jpg	butter_85.jpg
# butter_13.jpg	butter_194.jpg	butter_248.jpg	butter_31.jpg	butter_86.jpg
# butter_140.jpg	butter_195.jpg	butter_249.jpg	butter_32.jpg	butter_87.jpg
# butter_141.jpg	butter_196.jpg	butter_24.jpg	butter_33.jpg	butter_88.jpg
# butter_142.jpg	butter_197.jpg	butter_250.jpg	butter_34.jpg	butter_89.jpg
# butter_143.jpg	butter_198.jpg	butter_251.jpg	butter_35.jpg	butter_8.jpg
# butter_144.jpg	butter_199.jpg	butter_252.jpg	butter_36.jpg	butter_90.jpg
# butter_145.jpg	butter_19.jpg	butter_253.jpg	butter_37.jpg	butter_91.jpg
# butter_146.jpg	butter_1.jpg	butter_254.jpg	butter_38.jpg	butter_92.jpg
# butter_147.jpg	butter_200.jpg	butter_255.jpg	butter_39.jpg	butter_93.jpg
# butter_148.jpg	butter_201.jpg	butter_256.jpg	butter_3.jpg	butter_94.jpg
# butter_149.jpg	butter_202.jpg	butter_257.jpg	butter_40.jpg	butter_95.jpg
# butter_14.jpg	butter_203.jpg	butter_258.jpg	butter_41.jpg	butter_96.jpg
# butter_150.jpg	butter_204.jpg	butter_259.jpg	butter_42.jpg	butter_97.jpg
# butter_151.jpg	butter_205.jpg	butter_25.jpg	butter_43.jpg	butter_98.jpg
# butter_152.jpg	butter_206.jpg	butter_260.jpg	butter_44.jpg	butter_99.jpg
# butter_153.jpg	butter_207.jpg	butter_261.jpg	butter_45.jpg	butter_9.jpg
#
# dataset/dataset/cake:
# cake_0.jpg    cake_154.jpg  cake_208.jpg  cake_262.jpg	cake_46.jpg
# cake_100.jpg  cake_155.jpg  cake_209.jpg  cake_263.jpg	cake_47.jpg
# cake_101.jpg  cake_156.jpg  cake_20.jpg   cake_264.jpg	cake_48.jpg
# cake_102.jpg  cake_157.jpg  cake_210.jpg  cake_265.jpg	cake_49.jpg
# cake_103.jpg  cake_158.jpg  cake_211.jpg  cake_266.jpg	cake_4.jpg
# cake_104.jpg  cake_159.jpg  cake_212.jpg  cake_267.jpg	cake_50.jpg
# cake_105.jpg  cake_15.jpg   cake_213.jpg  cake_268.jpg	cake_51.jpg
# cake_106.jpg  cake_160.jpg  cake_214.jpg  cake_269.jpg	cake_52.jpg
# cake_107.jpg  cake_161.jpg  cake_215.jpg  cake_26.jpg	cake_53.jpg
# cake_108.jpg  cake_162.jpg  cake_216.jpg  cake_270.jpg	cake_54.jpg
# cake_109.jpg  cake_163.jpg  cake_217.jpg  cake_271.jpg	cake_55.jpg
# cake_10.jpg   cake_164.jpg  cake_218.jpg  cake_272.jpg	cake_56.jpg
# cake_110.jpg  cake_165.jpg  cake_219.jpg  cake_273.jpg	cake_57.jpg
# cake_111.jpg  cake_166.jpg  cake_21.jpg   cake_274.jpg	cake_58.jpg
# cake_112.jpg  cake_167.jpg  cake_220.jpg  cake_275.jpg	cake_59.jpg
# cake_113.jpg  cake_168.jpg  cake_221.jpg  cake_276.jpg	cake_5.jpg
# cake_114.jpg  cake_169.jpg  cake_222.jpg  cake_277.jpg	cake_60.jpg
# cake_115.jpg  cake_16.jpg   cake_223.jpg  cake_278.jpg	cake_61.jpg
# cake_116.jpg  cake_170.jpg  cake_224.jpg  cake_279.jpg	cake_62.jpg
# cake_117.jpg  cake_171.jpg  cake_225.jpg  cake_27.jpg	cake_63.jpg
# cake_118.jpg  cake_172.jpg  cake_226.jpg  cake_280.jpg	cake_64.jpg
# cake_119.jpg  cake_173.jpg  cake_227.jpg  cake_281.jpg	cake_65.jpg
# cake_11.jpg   cake_174.jpg  cake_228.jpg  cake_282.jpg	cake_66.jpg
# cake_120.jpg  cake_175.jpg  cake_229.jpg  cake_283.jpg	cake_67.jpg
# cake_121.jpg  cake_176.jpg  cake_22.jpg   cake_284.jpg	cake_68.jpg
# cake_122.jpg  cake_177.jpg  cake_230.jpg  cake_285.jpg	cake_69.jpg
# cake_123.jpg  cake_178.jpg  cake_231.jpg  cake_286.jpg	cake_6.jpg
# cake_124.jpg  cake_179.jpg  cake_232.jpg  cake_287.jpg	cake_70.jpg
# cake_125.jpg  cake_17.jpg   cake_233.jpg  cake_288.jpg	cake_71.jpg
# cake_126.jpg  cake_180.jpg  cake_234.jpg  cake_289.jpg	cake_72.jpg
# cake_127.jpg  cake_181.jpg  cake_235.jpg  cake_28.jpg	cake_73.jpg
# cake_128.jpg  cake_182.jpg  cake_236.jpg  cake_290.jpg	cake_74.jpg
# cake_129.jpg  cake_183.jpg  cake_237.jpg  cake_291.jpg	cake_75.jpg
# cake_12.jpg   cake_184.jpg  cake_238.jpg  cake_292.jpg	cake_76.jpg
# cake_130.jpg  cake_185.jpg  cake_239.jpg  cake_293.jpg	cake_77.jpg
# cake_131.jpg  cake_186.jpg  cake_23.jpg   cake_294.jpg	cake_78.jpg
# cake_132.jpg  cake_187.jpg  cake_240.jpg  cake_295.jpg	cake_79.jpg
# cake_133.jpg  cake_188.jpg  cake_241.jpg  cake_296.jpg	cake_7.jpg
# cake_134.jpg  cake_189.jpg  cake_242.jpg  cake_297.jpg	cake_80.jpg
# cake_135.jpg  cake_18.jpg   cake_243.jpg  cake_298.jpg	cake_81.jpg
# cake_136.jpg  cake_190.jpg  cake_244.jpg  cake_299.jpg	cake_82.jpg
# cake_137.jpg  cake_191.jpg  cake_245.jpg  cake_29.jpg	cake_83.jpg
# cake_138.jpg  cake_192.jpg  cake_246.jpg  cake_2.jpg	cake_84.jpg
# cake_139.jpg  cake_193.jpg  cake_247.jpg  cake_30.jpg	cake_85.jpg
# cake_13.jpg   cake_194.jpg  cake_248.jpg  cake_31.jpg	cake_86.jpg
# cake_140.jpg  cake_195.jpg  cake_249.jpg  cake_32.jpg	cake_87.jpg
# cake_141.jpg  cake_196.jpg  cake_24.jpg   cake_33.jpg	cake_88.jpg
# cake_142.jpg  cake_197.jpg  cake_250.jpg  cake_34.jpg	cake_89.jpg
# cake_143.jpg  cake_198.jpg  cake_251.jpg  cake_35.jpg	cake_8.jpg
# cake_144.jpg  cake_199.jpg  cake_252.jpg  cake_36.jpg	cake_90.jpg
# cake_145.jpg  cake_19.jpg   cake_253.jpg  cake_37.jpg	cake_91.jpg
# cake_146.jpg  cake_1.jpg    cake_254.jpg  cake_38.jpg	cake_92.jpg
# cake_147.jpg  cake_200.jpg  cake_255.jpg  cake_39.jpg	cake_93.jpg
# cake_148.jpg  cake_201.jpg  cake_256.jpg  cake_3.jpg	cake_94.jpg
# cake_149.jpg  cake_202.jpg  cake_257.jpg  cake_40.jpg	cake_95.jpg
# cake_14.jpg   cake_203.jpg  cake_258.jpg  cake_41.jpg	cake_96.jpg
# cake_150.jpg  cake_204.jpg  cake_259.jpg  cake_42.jpg	cake_97.jpg
# cake_151.jpg  cake_205.jpg  cake_25.jpg   cake_43.jpg	cake_98.jpg
# cake_152.jpg  cake_206.jpg  cake_260.jpg  cake_44.jpg	cake_99.jpg
# cake_153.jpg  cake_207.jpg  cake_261.jpg  cake_45.jpg	cake_9.jpg
#
# dataset/dataset/carrot:
# carrot_0.jpg	carrot_154.jpg	carrot_208.jpg	carrot_262.jpg	carrot_46.jpg
# carrot_100.jpg	carrot_155.jpg	carrot_209.jpg	carrot_263.jpg	carrot_47.jpg
# carrot_101.jpg	carrot_156.jpg	carrot_20.jpg	carrot_264.jpg	carrot_48.jpg
# carrot_102.jpg	carrot_157.jpg	carrot_210.jpg	carrot_265.jpg	carrot_49.jpg
# carrot_103.jpg	carrot_158.jpg	carrot_211.jpg	carrot_266.jpg	carrot_4.jpg
# carrot_104.jpg	carrot_159.jpg	carrot_212.jpg	carrot_267.jpg	carrot_50.jpg
# carrot_105.jpg	carrot_15.jpg	carrot_213.jpg	carrot_268.jpg	carrot_51.jpg
# carrot_106.jpg	carrot_160.jpg	carrot_214.jpg	carrot_269.jpg	carrot_52.jpg
# carrot_107.jpg	carrot_161.jpg	carrot_215.jpg	carrot_26.jpg	carrot_53.jpg
# carrot_108.jpg	carrot_162.jpg	carrot_216.jpg	carrot_270.jpg	carrot_54.jpg
# carrot_109.jpg	carrot_163.jpg	carrot_217.jpg	carrot_271.jpg	carrot_55.jpg
# carrot_10.jpg	carrot_164.jpg	carrot_218.jpg	carrot_272.jpg	carrot_56.jpg
# carrot_110.jpg	carrot_165.jpg	carrot_219.jpg	carrot_273.jpg	carrot_57.jpg
# carrot_111.jpg	carrot_166.jpg	carrot_21.jpg	carrot_274.jpg	carrot_58.jpg
# carrot_112.jpg	carrot_167.jpg	carrot_220.jpg	carrot_275.jpg	carrot_59.jpg
# carrot_113.jpg	carrot_168.jpg	carrot_221.jpg	carrot_276.jpg	carrot_5.jpg
# carrot_114.jpg	carrot_169.jpg	carrot_222.jpg	carrot_277.jpg	carrot_60.jpg
# carrot_115.jpg	carrot_16.jpg	carrot_223.jpg	carrot_278.jpg	carrot_61.jpg
# carrot_116.jpg	carrot_170.jpg	carrot_224.jpg	carrot_279.jpg	carrot_62.jpg
# carrot_117.jpg	carrot_171.jpg	carrot_225.jpg	carrot_27.jpg	carrot_63.jpg
# carrot_118.jpg	carrot_172.jpg	carrot_226.jpg	carrot_280.jpg	carrot_64.jpg
# carrot_119.jpg	carrot_173.jpg	carrot_227.jpg	carrot_281.jpg	carrot_65.jpg
# carrot_11.jpg	carrot_174.jpg	carrot_228.jpg	carrot_282.jpg	carrot_66.jpg
# carrot_120.jpg	carrot_175.jpg	carrot_229.jpg	carrot_283.jpg	carrot_67.jpg
# carrot_121.jpg	carrot_176.jpg	carrot_22.jpg	carrot_284.jpg	carrot_68.jpg
# carrot_122.jpg	carrot_177.jpg	carrot_230.jpg	carrot_285.jpg	carrot_69.jpg
# carrot_123.jpg	carrot_178.jpg	carrot_231.jpg	carrot_286.jpg	carrot_6.jpg
# carrot_124.jpg	carrot_179.jpg	carrot_232.jpg	carrot_287.jpg	carrot_70.jpg
# carrot_125.jpg	carrot_17.jpg	carrot_233.jpg	carrot_288.jpg	carrot_71.jpg
# carrot_126.jpg	carrot_180.jpg	carrot_234.jpg	carrot_289.jpg	carrot_72.jpg
# carrot_127.jpg	carrot_181.jpg	carrot_235.jpg	carrot_28.jpg	carrot_73.jpg
# carrot_128.jpg	carrot_182.jpg	carrot_236.jpg	carrot_290.jpg	carrot_74.jpg
# carrot_129.jpg	carrot_183.jpg	carrot_237.jpg	carrot_291.jpg	carrot_75.jpg
# carrot_12.jpg	carrot_184.jpg	carrot_238.jpg	carrot_292.jpg	carrot_76.jpg
# carrot_130.jpg	carrot_185.jpg	carrot_239.jpg	carrot_293.jpg	carrot_77.jpg
# carrot_131.jpg	carrot_186.jpg	carrot_23.jpg	carrot_294.jpg	carrot_78.jpg
# carrot_132.jpg	carrot_187.jpg	carrot_240.jpg	carrot_295.jpg	carrot_79.jpg
# carrot_133.jpg	carrot_188.jpg	carrot_241.jpg	carrot_296.jpg	carrot_7.jpg
# carrot_134.jpg	carrot_189.jpg	carrot_242.jpg	carrot_297.jpg	carrot_80.jpg
# carrot_135.jpg	carrot_18.jpg	carrot_243.jpg	carrot_298.jpg	carrot_81.jpg
# carrot_136.jpg	carrot_190.jpg	carrot_244.jpg	carrot_299.jpg	carrot_82.jpg
# carrot_137.jpg	carrot_191.jpg	carrot_245.jpg	carrot_29.jpg	carrot_83.jpg
# carrot_138.jpg	carrot_192.jpg	carrot_246.jpg	carrot_2.jpg	carrot_84.jpg
# carrot_139.jpg	carrot_193.jpg	carrot_247.jpg	carrot_30.jpg	carrot_85.jpg
# carrot_13.jpg	carrot_194.jpg	carrot_248.jpg	carrot_31.jpg	carrot_86.jpg
# carrot_140.jpg	carrot_195.jpg	carrot_249.jpg	carrot_32.jpg	carrot_87.jpg
# carrot_141.jpg	carrot_196.jpg	carrot_24.jpg	carrot_33.jpg	carrot_88.jpg
# carrot_142.jpg	carrot_197.jpg	carrot_250.jpg	carrot_34.jpg	carrot_89.jpg
# carrot_143.jpg	carrot_198.jpg	carrot_251.jpg	carrot_35.jpg	carrot_8.jpg
# carrot_144.jpg	carrot_199.jpg	carrot_252.jpg	carrot_36.jpg	carrot_90.jpg
# carrot_145.jpg	carrot_19.jpg	carrot_253.jpg	carrot_37.jpg	carrot_91.jpg
# carrot_146.jpg	carrot_1.jpg	carrot_254.jpg	carrot_38.jpg	carrot_92.jpg
# carrot_147.jpg	carrot_200.jpg	carrot_255.jpg	carrot_39.jpg	carrot_93.jpg
# carrot_148.jpg	carrot_201.jpg	carrot_256.jpg	carrot_3.jpg	carrot_94.jpg
# carrot_149.jpg	carrot_202.jpg	carrot_257.jpg	carrot_40.jpg	carrot_95.jpg
# carrot_14.jpg	carrot_203.jpg	carrot_258.jpg	carrot_41.jpg	carrot_96.jpg
# carrot_150.jpg	carrot_204.jpg	carrot_259.jpg	carrot_42.jpg	carrot_97.jpg
# carrot_151.jpg	carrot_205.jpg	carrot_25.jpg	carrot_43.jpg	carrot_98.jpg
# carrot_152.jpg	carrot_206.jpg	carrot_260.jpg	carrot_44.jpg	carrot_99.jpg
# carrot_153.jpg	carrot_207.jpg	carrot_261.jpg	carrot_45.jpg	carrot_9.jpg
#
# dataset/dataset/cheese:
# cheese_0.jpg	cheese_154.jpg	cheese_208.jpg	cheese_262.jpg	cheese_46.jpg
# cheese_100.jpg	cheese_155.jpg	cheese_209.jpg	cheese_263.jpg	cheese_47.jpg
# cheese_101.jpg	cheese_156.jpg	cheese_20.jpg	cheese_264.jpg	cheese_48.jpg
# cheese_102.jpg	cheese_157.jpg	cheese_210.jpg	cheese_265.jpg	cheese_49.jpg
# cheese_103.jpg	cheese_158.jpg	cheese_211.jpg	cheese_266.jpg	cheese_4.jpg
# cheese_104.jpg	cheese_159.jpg	cheese_212.jpg	cheese_267.jpg	cheese_50.jpg
# cheese_105.jpg	cheese_15.jpg	cheese_213.jpg	cheese_268.jpg	cheese_51.jpg
# cheese_106.jpg	cheese_160.jpg	cheese_214.jpg	cheese_269.jpg	cheese_52.jpg
# cheese_107.jpg	cheese_161.jpg	cheese_215.jpg	cheese_26.jpg	cheese_53.jpg
# cheese_108.jpg	cheese_162.jpg	cheese_216.jpg	cheese_270.jpg	cheese_54.jpg
# cheese_109.jpg	cheese_163.jpg	cheese_217.jpg	cheese_271.jpg	cheese_55.jpg
# cheese_10.jpg	cheese_164.jpg	cheese_218.jpg	cheese_272.jpg	cheese_56.jpg
# cheese_110.jpg	cheese_165.jpg	cheese_219.jpg	cheese_273.jpg	cheese_57.jpg
# cheese_111.jpg	cheese_166.jpg	cheese_21.jpg	cheese_274.jpg	cheese_58.jpg
# cheese_112.jpg	cheese_167.jpg	cheese_220.jpg	cheese_275.jpg	cheese_59.jpg
# cheese_113.jpg	cheese_168.jpg	cheese_221.jpg	cheese_276.jpg	cheese_5.jpg
# cheese_114.jpg	cheese_169.jpg	cheese_222.jpg	cheese_277.jpg	cheese_60.jpg
# cheese_115.jpg	cheese_16.jpg	cheese_223.jpg	cheese_278.jpg	cheese_61.jpg
# cheese_116.jpg	cheese_170.jpg	cheese_224.jpg	cheese_279.jpg	cheese_62.jpg
# cheese_117.jpg	cheese_171.jpg	cheese_225.jpg	cheese_27.jpg	cheese_63.jpg
# cheese_118.jpg	cheese_172.jpg	cheese_226.jpg	cheese_280.jpg	cheese_64.jpg
# ...
# tuna_136.jpg  tuna_190.jpg  tuna_244.jpg  tuna_299.jpg	tuna_82.jpg
# tuna_137.jpg  tuna_191.jpg  tuna_245.jpg  tuna_29.jpg	tuna_83.jpg
# tuna_138.jpg  tuna_192.jpg  tuna_246.jpg  tuna_2.jpg	tuna_84.jpg
# tuna_139.jpg  tuna_193.jpg  tuna_247.jpg  tuna_30.jpg	tuna_85.jpg
# tuna_13.jpg   tuna_194.jpg  tuna_248.jpg  tuna_31.jpg	tuna_86.jpg
# tuna_140.jpg  tuna_195.jpg  tuna_249.jpg  tuna_32.jpg	tuna_87.jpg
# tuna_141.jpg  tuna_196.jpg  tuna_24.jpg   tuna_33.jpg	tuna_88.jpg
# tuna_142.jpg  tuna_197.jpg  tuna_250.jpg  tuna_34.jpg	tuna_89.jpg
# tuna_143.jpg  tuna_198.jpg  tuna_251.jpg  tuna_35.jpg	tuna_8.jpg
# tuna_144.jpg  tuna_199.jpg  tuna_252.jpg  tuna_36.jpg	tuna_90.jpg
# tuna_145.jpg  tuna_19.jpg   tuna_253.jpg  tuna_37.jpg	tuna_91.jpg
# tuna_146.jpg  tuna_1.jpg    tuna_254.jpg  tuna_38.jpg	tuna_92.jpg
# tuna_147.jpg  tuna_200.jpg  tuna_255.jpg  tuna_39.jpg	tuna_93.jpg
# tuna_148.jpg  tuna_201.jpg  tuna_256.jpg  tuna_3.jpg	tuna_94.jpg
# tuna_149.jpg  tuna_202.jpg  tuna_257.jpg  tuna_40.jpg	tuna_95.jpg
# tuna_14.jpg   tuna_203.jpg  tuna_258.jpg  tuna_41.jpg	tuna_96.jpg
# tuna_150.jpg  tuna_204.jpg  tuna_259.jpg  tuna_42.jpg	tuna_97.jpg
# tuna_151.jpg  tuna_205.jpg  tuna_25.jpg   tuna_43.jpg	tuna_98.jpg
# tuna_152.jpg  tuna_206.jpg  tuna_260.jpg  tuna_44.jpg	tuna_99.jpg
# tuna_153.jpg  tuna_207.jpg  tuna_261.jpg  tuna_45.jpg	tuna_9.jpg
#
# dataset/dataset/turkey:
# turkey_0.jpg	turkey_154.jpg	turkey_208.jpg	turkey_262.jpg	turkey_46.jpg
# turkey_100.jpg	turkey_155.jpg	turkey_209.jpg	turkey_263.jpg	turkey_47.jpg
# turkey_101.jpg	turkey_156.jpg	turkey_20.jpg	turkey_264.jpg	turkey_48.jpg
# turkey_102.jpg	turkey_157.jpg	turkey_210.jpg	turkey_265.jpg	turkey_49.jpg
# turkey_103.jpg	turkey_158.jpg	turkey_211.jpg	turkey_266.jpg	turkey_4.jpg
# turkey_104.jpg	turkey_159.jpg	turkey_212.jpg	turkey_267.jpg	turkey_50.jpg
# turkey_105.jpg	turkey_15.jpg	turkey_213.jpg	turkey_268.jpg	turkey_51.jpg
# turkey_106.jpg	turkey_160.jpg	turkey_214.jpg	turkey_269.jpg	turkey_52.jpg
# turkey_107.jpg	turkey_161.jpg	turkey_215.jpg	turkey_26.jpg	turkey_53.jpg
# turkey_108.jpg	turkey_162.jpg	turkey_216.jpg	turkey_270.jpg	turkey_54.jpg
# turkey_109.jpg	turkey_163.jpg	turkey_217.jpg	turkey_271.jpg	turkey_55.jpg
# turkey_10.jpg	turkey_164.jpg	turkey_218.jpg	turkey_272.jpg	turkey_56.jpg
# turkey_110.jpg	turkey_165.jpg	turkey_219.jpg	turkey_273.jpg	turkey_57.jpg
# turkey_111.jpg	turkey_166.jpg	turkey_21.jpg	turkey_274.jpg	turkey_58.jpg
# turkey_112.jpg	turkey_167.jpg	turkey_220.jpg	turkey_275.jpg	turkey_59.jpg
# turkey_113.jpg	turkey_168.jpg	turkey_221.jpg	turkey_276.jpg	turkey_5.jpg
# turkey_114.jpg	turkey_169.jpg	turkey_222.jpg	turkey_277.jpg	turkey_60.jpg
# turkey_115.jpg	turkey_16.jpg	turkey_223.jpg	turkey_278.jpg	turkey_61.jpg
# turkey_116.jpg	turkey_170.jpg	turkey_224.jpg	turkey_279.jpg	turkey_62.jpg
# turkey_117.jpg	turkey_171.jpg	turkey_225.jpg	turkey_27.jpg	turkey_63.jpg
# turkey_118.jpg	turkey_172.jpg	turkey_226.jpg	turkey_280.jpg	turkey_64.jpg
# turkey_119.jpg	turkey_173.jpg	turkey_227.jpg	turkey_281.jpg	turkey_65.jpg
# turkey_11.jpg	turkey_174.jpg	turkey_228.jpg	turkey_282.jpg	turkey_66.jpg
# turkey_120.jpg	turkey_175.jpg	turkey_229.jpg	turkey_283.jpg	turkey_67.jpg
# turkey_121.jpg	turkey_176.jpg	turkey_22.jpg	turkey_284.jpg	turkey_68.jpg
# turkey_122.jpg	turkey_177.jpg	turkey_230.jpg	turkey_285.jpg	turkey_69.jpg
# turkey_123.jpg	turkey_178.jpg	turkey_231.jpg	turkey_286.jpg	turkey_6.jpg
# turkey_124.jpg	turkey_179.jpg	turkey_232.jpg	turkey_287.jpg	turkey_70.jpg
# turkey_125.jpg	turkey_17.jpg	turkey_233.jpg	turkey_288.jpg	turkey_71.jpg
# turkey_126.jpg	turkey_180.jpg	turkey_234.jpg	turkey_289.jpg	turkey_72.jpg
# turkey_127.jpg	turkey_181.jpg	turkey_235.jpg	turkey_28.jpg	turkey_73.jpg
# turkey_128.jpg	turkey_182.jpg	turkey_236.jpg	turkey_290.jpg	turkey_74.jpg
# turkey_129.jpg	turkey_183.jpg	turkey_237.jpg	turkey_291.jpg	turkey_75.jpg
# turkey_12.jpg	turkey_184.jpg	turkey_238.jpg	turkey_292.jpg	turkey_76.jpg
# turkey_130.jpg	turkey_185.jpg	turkey_239.jpg	turkey_293.jpg	turkey_77.jpg
# turkey_131.jpg	turkey_186.jpg	turkey_23.jpg	turkey_294.jpg	turkey_78.jpg
# turkey_132.jpg	turkey_187.jpg	turkey_240.jpg	turkey_295.jpg	turkey_79.jpg
# turkey_133.jpg	turkey_188.jpg	turkey_241.jpg	turkey_296.jpg	turkey_7.jpg
# turkey_134.jpg	turkey_189.jpg	turkey_242.jpg	turkey_297.jpg	turkey_80.jpg
# turkey_135.jpg	turkey_18.jpg	turkey_243.jpg	turkey_298.jpg	turkey_81.jpg
# turkey_136.jpg	turkey_190.jpg	turkey_244.jpg	turkey_299.jpg	turkey_82.jpg
# turkey_137.jpg	turkey_191.jpg	turkey_245.jpg	turkey_29.jpg	turkey_83.jpg
# turkey_138.jpg	turkey_192.jpg	turkey_246.jpg	turkey_2.jpg	turkey_84.jpg
# turkey_139.jpg	turkey_193.jpg	turkey_247.jpg	turkey_30.jpg	turkey_85.jpg
# turkey_13.jpg	turkey_194.jpg	turkey_248.jpg	turkey_31.jpg	turkey_86.jpg
# turkey_140.jpg	turkey_195.jpg	turkey_249.jpg	turkey_32.jpg	turkey_87.jpg
# turkey_141.jpg	turkey_196.jpg	turkey_24.jpg	turkey_33.jpg	turkey_88.jpg
# turkey_142.jpg	turkey_197.jpg	turkey_250.jpg	turkey_34.jpg	turkey_89.jpg
# turkey_143.jpg	turkey_198.jpg	turkey_251.jpg	turkey_35.jpg	turkey_8.jpg
# turkey_144.jpg	turkey_199.jpg	turkey_252.jpg	turkey_36.jpg	turkey_90.jpg
# turkey_145.jpg	turkey_19.jpg	turkey_253.jpg	turkey_37.jpg	turkey_91.jpg
# turkey_146.jpg	turkey_1.jpg	turkey_254.jpg	turkey_38.jpg	turkey_92.jpg
# turkey_147.jpg	turkey_200.jpg	turkey_255.jpg	turkey_39.jpg	turkey_93.jpg
# turkey_148.jpg	turkey_201.jpg	turkey_256.jpg	turkey_3.jpg	turkey_94.jpg
# turkey_149.jpg	turkey_202.jpg	turkey_257.jpg	turkey_40.jpg	turkey_95.jpg
# turkey_14.jpg	turkey_203.jpg	turkey_258.jpg	turkey_41.jpg	turkey_96.jpg
# turkey_150.jpg	turkey_204.jpg	turkey_259.jpg	turkey_42.jpg	turkey_97.jpg
# turkey_151.jpg	turkey_205.jpg	turkey_25.jpg	turkey_43.jpg	turkey_98.jpg
# turkey_152.jpg	turkey_206.jpg	turkey_260.jpg	turkey_44.jpg	turkey_99.jpg
# turkey_153.jpg	turkey_207.jpg	turkey_261.jpg	turkey_45.jpg	turkey_9.jpg
#
# dataset/dataset/watermelon:
# watermelon_0.jpg    watermelon_168.jpg	watermelon_235.jpg  watermelon_32.jpg
# watermelon_100.jpg  watermelon_169.jpg	watermelon_236.jpg  watermelon_33.jpg
# watermelon_101.jpg  watermelon_16.jpg	watermelon_237.jpg  watermelon_34.jpg
# watermelon_102.jpg  watermelon_170.jpg	watermelon_238.jpg  watermelon_35.jpg
# watermelon_103.jpg  watermelon_171.jpg	watermelon_239.jpg  watermelon_36.jpg
# watermelon_104.jpg  watermelon_172.jpg	watermelon_23.jpg   watermelon_37.jpg
# watermelon_105.jpg  watermelon_173.jpg	watermelon_240.jpg  watermelon_38.jpg
# watermelon_106.jpg  watermelon_174.jpg	watermelon_241.jpg  watermelon_39.jpg
# watermelon_107.jpg  watermelon_175.jpg	watermelon_242.jpg  watermelon_3.jpg
# watermelon_108.jpg  watermelon_176.jpg	watermelon_243.jpg  watermelon_40.jpg
# watermelon_109.jpg  watermelon_177.jpg	watermelon_244.jpg  watermelon_41.jpg
# watermelon_10.jpg   watermelon_178.jpg	watermelon_245.jpg  watermelon_42.jpg
# watermelon_110.jpg  watermelon_179.jpg	watermelon_246.jpg  watermelon_43.jpg
# watermelon_111.jpg  watermelon_17.jpg	watermelon_247.jpg  watermelon_44.jpg
# watermelon_112.jpg  watermelon_180.jpg	watermelon_248.jpg  watermelon_45.jpg
# watermelon_113.jpg  watermelon_181.jpg	watermelon_249.jpg  watermelon_46.jpg
# watermelon_114.jpg  watermelon_182.jpg	watermelon_24.jpg   watermelon_47.jpg
# watermelon_115.jpg  watermelon_183.jpg	watermelon_250.jpg  watermelon_48.jpg
# watermelon_116.jpg  watermelon_184.jpg	watermelon_251.jpg  watermelon_49.jpg
# watermelon_117.jpg  watermelon_185.jpg	watermelon_252.jpg  watermelon_4.jpg
# watermelon_118.jpg  watermelon_186.jpg	watermelon_253.jpg  watermelon_50.jpg
# watermelon_119.jpg  watermelon_187.jpg	watermelon_254.jpg  watermelon_51.jpg
# watermelon_11.jpg   watermelon_188.jpg	watermelon_255.jpg  watermelon_52.jpg
# watermelon_120.jpg  watermelon_189.jpg	watermelon_256.jpg  watermelon_53.jpg
# watermelon_121.jpg  watermelon_18.jpg	watermelon_257.jpg  watermelon_54.jpg
# watermelon_122.jpg  watermelon_190.jpg	watermelon_258.jpg  watermelon_55.jpg
# watermelon_123.jpg  watermelon_191.jpg	watermelon_259.jpg  watermelon_56.jpg
# watermelon_124.jpg  watermelon_192.jpg	watermelon_25.jpg   watermelon_57.jpg
# watermelon_125.jpg  watermelon_193.jpg	watermelon_260.jpg  watermelon_58.jpg
# watermelon_126.jpg  watermelon_194.jpg	watermelon_261.jpg  watermelon_59.jpg
# watermelon_127.jpg  watermelon_195.jpg	watermelon_262.jpg  watermelon_5.jpg
# watermelon_128.jpg  watermelon_196.jpg	watermelon_263.jpg  watermelon_60.jpg
# watermelon_129.jpg  watermelon_197.jpg	watermelon_264.jpg  watermelon_61.jpg
# watermelon_12.jpg   watermelon_198.jpg	watermelon_265.jpg  watermelon_62.jpg
# watermelon_130.jpg  watermelon_199.jpg	watermelon_266.jpg  watermelon_63.jpg
# watermelon_131.jpg  watermelon_19.jpg	watermelon_267.jpg  watermelon_64.jpg
# watermelon_132.jpg  watermelon_1.jpg	watermelon_268.jpg  watermelon_65.jpg
# watermelon_133.jpg  watermelon_200.jpg	watermelon_269.jpg  watermelon_66.jpg
# watermelon_134.jpg  watermelon_201.jpg	watermelon_26.jpg   watermelon_67.jpg
# watermelon_135.jpg  watermelon_202.jpg	watermelon_270.jpg  watermelon_68.jpg
# watermelon_136.jpg  watermelon_203.jpg	watermelon_271.jpg  watermelon_69.jpg
# watermelon_137.jpg  watermelon_204.jpg	watermelon_272.jpg  watermelon_6.jpg
# watermelon_138.jpg  watermelon_205.jpg	watermelon_273.jpg  watermelon_70.jpg
# watermelon_139.jpg  watermelon_206.jpg	watermelon_274.jpg  watermelon_71.jpg
# watermelon_13.jpg   watermelon_207.jpg	watermelon_275.jpg  watermelon_72.jpg
# watermelon_140.jpg  watermelon_208.jpg	watermelon_276.jpg  watermelon_73.jpg
# watermelon_141.jpg  watermelon_209.jpg	watermelon_277.jpg  watermelon_74.jpg
# watermelon_142.jpg  watermelon_20.jpg	watermelon_278.jpg  watermelon_75.jpg
# watermelon_143.jpg  watermelon_210.jpg	watermelon_279.jpg  watermelon_76.jpg
# watermelon_144.jpg  watermelon_211.jpg	watermelon_27.jpg   watermelon_77.jpg
# watermelon_145.jpg  watermelon_212.jpg	watermelon_280.jpg  watermelon_78.jpg
# watermelon_146.jpg  watermelon_213.jpg	watermelon_281.jpg  watermelon_79.jpg
# watermelon_147.jpg  watermelon_214.jpg	watermelon_282.jpg  watermelon_7.jpg
# watermelon_148.jpg  watermelon_215.jpg	watermelon_283.jpg  watermelon_80.jpg
# watermelon_149.jpg  watermelon_216.jpg	watermelon_284.jpg  watermelon_81.jpg
# watermelon_14.jpg   watermelon_217.jpg	watermelon_285.jpg  watermelon_82.jpg
# watermelon_150.jpg  watermelon_218.jpg	watermelon_286.jpg  watermelon_83.jpg
# watermelon_151.jpg  watermelon_219.jpg	watermelon_287.jpg  watermelon_84.jpg
# watermelon_152.jpg  watermelon_21.jpg	watermelon_288.jpg  watermelon_85.jpg
# watermelon_153.jpg  watermelon_220.jpg	watermelon_289.jpg  watermelon_86.jpg
# watermelon_154.jpg  watermelon_221.jpg	watermelon_28.jpg   watermelon_87.jpg
# watermelon_155.jpg  watermelon_222.jpg	watermelon_290.jpg  watermelon_88.jpg
# watermelon_156.jpg  watermelon_223.jpg	watermelon_291.jpg  watermelon_89.jpg
# watermelon_157.jpg  watermelon_224.jpg	watermelon_292.jpg  watermelon_8.jpg
# watermelon_158.jpg  watermelon_225.jpg	watermelon_293.jpg  watermelon_90.jpg
# watermelon_159.jpg  watermelon_226.jpg	watermelon_294.jpg  watermelon_91.jpg
# watermelon_15.jpg   watermelon_227.jpg	watermelon_295.jpg  watermelon_92.jpg
# watermelon_160.jpg  watermelon_228.jpg	watermelon_296.jpg  watermelon_93.jpg
# watermelon_161.jpg  watermelon_229.jpg	watermelon_297.jpg  watermelon_94.jpg
# watermelon_162.jpg  watermelon_22.jpg	watermelon_298.jpg  watermelon_95.jpg
# watermelon_163.jpg  watermelon_230.jpg	watermelon_299.jpg  watermelon_96.jpg
# watermelon_164.jpg  watermelon_231.jpg	watermelon_29.jpg   watermelon_97.jpg
# watermelon_165.jpg  watermelon_232.jpg	watermelon_2.jpg    watermelon_98.jpg
# watermelon_166.jpg  watermelon_233.jpg	watermelon_30.jpg   watermelon_99.jpg
# watermelon_167.jpg  watermelon_234.jpg	watermelon_31.jpg   watermelon_9.jpg
#
# dataset/dataset/yogurt:
# yogurt_0.jpg	yogurt_154.jpg	yogurt_208.jpg	yogurt_262.jpg	yogurt_46.jpg
# yogurt_100.jpg	yogurt_155.jpg	yogurt_209.jpg	yogurt_263.jpg	yogurt_47.jpg
# yogurt_101.jpg	yogurt_156.jpg	yogurt_20.jpg	yogurt_264.jpg	yogurt_48.jpg
# yogurt_102.jpg	yogurt_157.jpg	yogurt_210.jpg	yogurt_265.jpg	yogurt_49.jpg
# yogurt_103.jpg	yogurt_158.jpg	yogurt_211.jpg	yogurt_266.jpg	yogurt_4.jpg
# yogurt_104.jpg	yogurt_159.jpg	yogurt_212.jpg	yogurt_267.jpg	yogurt_50.jpg
# yogurt_105.jpg	yogurt_15.jpg	yogurt_213.jpg	yogurt_268.jpg	yogurt_51.jpg
# yogurt_106.jpg	yogurt_160.jpg	yogurt_214.jpg	yogurt_269.jpg	yogurt_52.jpg
# yogurt_107.jpg	yogurt_161.jpg	yogurt_215.jpg	yogurt_26.jpg	yogurt_53.jpg
# yogurt_108.jpg	yogurt_162.jpg	yogurt_216.jpg	yogurt_270.jpg	yogurt_54.jpg
# yogurt_109.jpg	yogurt_163.jpg	yogurt_217.jpg	yogurt_271.jpg	yogurt_55.jpg
# yogurt_10.jpg	yogurt_164.jpg	yogurt_218.jpg	yogurt_272.jpg	yogurt_56.jpg
# yogurt_110.jpg	yogurt_165.jpg	yogurt_219.jpg	yogurt_273.jpg	yogurt_57.jpg
# yogurt_111.jpg	yogurt_166.jpg	yogurt_21.jpg	yogurt_274.jpg	yogurt_58.jpg
# yogurt_112.jpg	yogurt_167.jpg	yogurt_220.jpg	yogurt_275.jpg	yogurt_59.jpg
# yogurt_113.jpg	yogurt_168.jpg	yogurt_221.jpg	yogurt_276.jpg	yogurt_5.jpg
# yogurt_114.jpg	yogurt_169.jpg	yogurt_222.jpg	yogurt_277.jpg	yogurt_60.jpg
# yogurt_115.jpg	yogurt_16.jpg	yogurt_223.jpg	yogurt_278.jpg	yogurt_61.jpg
# yogurt_116.jpg	yogurt_170.jpg	yogurt_224.jpg	yogurt_279.jpg	yogurt_62.jpg
# yogurt_117.jpg	yogurt_171.jpg	yogurt_225.jpg	yogurt_27.jpg	yogurt_63.jpg
# yogurt_118.jpg	yogurt_172.jpg	yogurt_226.jpg	yogurt_280.jpg	yogurt_64.jpg
# yogurt_119.jpg	yogurt_173.jpg	yogurt_227.jpg	yogurt_281.jpg	yogurt_65.jpg
# yogurt_11.jpg	yogurt_174.jpg	yogurt_228.jpg	yogurt_282.jpg	yogurt_66.jpg
# yogurt_120.jpg	yogurt_175.jpg	yogurt_229.jpg	yogurt_283.jpg	yogurt_67.jpg
# yogurt_121.jpg	yogurt_176.jpg	yogurt_22.jpg	yogurt_284.jpg	yogurt_68.jpg
# yogurt_122.jpg	yogurt_177.jpg	yogurt_230.jpg	yogurt_285.jpg	yogurt_69.jpg
# yogurt_123.jpg	yogurt_178.jpg	yogurt_231.jpg	yogurt_286.jpg	yogurt_6.jpg
# yogurt_124.jpg	yogurt_179.jpg	yogurt_232.jpg	yogurt_287.jpg	yogurt_70.jpg
# yogurt_125.jpg	yogurt_17.jpg	yogurt_233.jpg	yogurt_288.jpg	yogurt_71.jpg
# yogurt_126.jpg	yogurt_180.jpg	yogurt_234.jpg	yogurt_289.jpg	yogurt_72.jpg
# yogurt_127.jpg	yogurt_181.jpg	yogurt_235.jpg	yogurt_28.jpg	yogurt_73.jpg
# yogurt_128.jpg	yogurt_182.jpg	yogurt_236.jpg	yogurt_290.jpg	yogurt_74.jpg
# yogurt_129.jpg	yogurt_183.jpg	yogurt_237.jpg	yogurt_291.jpg	yogurt_75.jpg
# yogurt_12.jpg	yogurt_184.jpg	yogurt_238.jpg	yogurt_292.jpg	yogurt_76.jpg
# yogurt_130.jpg	yogurt_185.jpg	yogurt_239.jpg	yogurt_293.jpg	yogurt_77.jpg
# yogurt_131.jpg	yogurt_186.jpg	yogurt_23.jpg	yogurt_294.jpg	yogurt_78.jpg
# yogurt_132.jpg	yogurt_187.jpg	yogurt_240.jpg	yogurt_295.jpg	yogurt_79.jpg
# yogurt_133.jpg	yogurt_188.jpg	yogurt_241.jpg	yogurt_296.jpg	yogurt_7.jpg
# yogurt_134.jpg	yogurt_189.jpg	yogurt_242.jpg	yogurt_297.jpg	yogurt_80.jpg
# yogurt_135.jpg	yogurt_18.jpg	yogurt_243.jpg	yogurt_298.jpg	yogurt_81.jpg
# yogurt_136.jpg	yogurt_190.jpg	yogurt_244.jpg	yogurt_299.jpg	yogurt_82.jpg
# yogurt_137.jpg	yogurt_191.jpg	yogurt_245.jpg	yogurt_29.jpg	yogurt_83.jpg
# yogurt_138.jpg	yogurt_192.jpg	yogurt_246.jpg	yogurt_2.jpg	yogurt_84.jpg
# yogurt_139.jpg	yogurt_193.jpg	yogurt_247.jpg	yogurt_30.jpg	yogurt_85.jpg
# yogurt_13.jpg	yogurt_194.jpg	yogurt_248.jpg	yogurt_31.jpg	yogurt_86.jpg
# yogurt_140.jpg	yogurt_195.jpg	yogurt_249.jpg	yogurt_32.jpg	yogurt_87.jpg
# yogurt_141.jpg	yogurt_196.jpg	yogurt_24.jpg	yogurt_33.jpg	yogurt_88.jpg
# yogurt_142.jpg	yogurt_197.jpg	yogurt_250.jpg	yogurt_34.jpg	yogurt_89.jpg
# yogurt_143.jpg	yogurt_198.jpg	yogurt_251.jpg	yogurt_35.jpg	yogurt_8.jpg
# yogurt_144.jpg	yogurt_199.jpg	yogurt_252.jpg	yogurt_36.jpg	yogurt_90.jpg
# yogurt_145.jpg	yogurt_19.jpg	yogurt_253.jpg	yogurt_37.jpg	yogurt_91.jpg
# yogurt_146.jpg	yogurt_1.jpg	yogurt_254.jpg	yogurt_38.jpg	yogurt_92.jpg
# yogurt_147.jpg	yogurt_200.jpg	yogurt_255.jpg	yogurt_39.jpg	yogurt_93.jpg
# yogurt_148.jpg	yogurt_201.jpg	yogurt_256.jpg	yogurt_3.jpg	yogurt_94.jpg
# yogurt_149.jpg	yogurt_202.jpg	yogurt_257.jpg	yogurt_40.jpg	yogurt_95.jpg
# yogurt_14.jpg	yogurt_203.jpg	yogurt_258.jpg	yogurt_41.jpg	yogurt_96.jpg
# yogurt_150.jpg	yogurt_204.jpg	yogurt_259.jpg	yogurt_42.jpg	yogurt_97.jpg
# yogurt_151.jpg	yogurt_205.jpg	yogurt_25.jpg	yogurt_43.jpg	yogurt_98.jpg
# yogurt_152.jpg	yogurt_206.jpg	yogurt_260.jpg	yogurt_44.jpg	yogurt_99.jpg
# yogurt_153.jpg	yogurt_207.jpg	yogurt_261.jpg	yogurt_45.jpg	yogurt_9.jpg

# %% [markdown]
# ## 3. Load Image Dataset

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

IMG_SIZE   = (224, 224)   # MobileNetV2 native size
BATCH_SIZE = 32
DATA_DIR   = 'dataset/dataset'

train_ds = image_dataset_from_directory(
    DATA_DIR, validation_split=0.2, subset='training',
    seed=42, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)
val_ds = image_dataset_from_directory(
    DATA_DIR, validation_split=0.2, subset='validation',
    seed=42, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
num_classes = len(class_names)
print(f'{num_classes} classes:', class_names)

AUTOTUNE = tf.data.AUTOTUNE
# No caching before augmentation — keeps augmentation random each epoch
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
# Out:
# Found 18120 files belonging to 64 classes.
# Using 14496 files for training.
# Found 18120 files belonging to 64 classes.
# Using 3624 files for validation.
# 64 classes: ['apple', 'bakery', 'banana', 'beef', 'bread', 'breakfast', 'broccoli', 'burger', 'burrito', 'butter', 'cake', 'carrot', 'cheese', 'chicken', 'chips', 'chocolate', 'coffee', 'cookies', 'corn', 'cream', 'cucumber', 'duck', 'falafel', 'fish', 'fried_chicken', 'garlic', 'grape', 'hummus', 'ice_cream', 'juice', 'kebab', 'lamb', 'lasagna', 'lettuce', 'mango', 'milk', 'noodles', 'oats', 'onion', 'orange', 'pasta', 'pineapple', 'pizza', 'popcorn', 'potato', 'quinoa', 'rice', 'salad', 'salmon', 'sandwich', 'shawarma', 'shrimp', 'smoothie', 'spinach', 'strawberry', 'sushi', 'sweet_potato', 'taco', 'tea', 'tomato', 'tuna', 'turkey', 'watermelon', 'yogurt']

# %% [markdown]
# ## 4. Build CNN Model (MobileNetV2 Transfer Learning)
#
# **Why MobileNetV2?**
# - Pretrained on ImageNet → already knows edges, textures, shapes
# - Achieves 60%+ on 64-class food datasets out of the box
# - Custom CNN from scratch gets stuck at ~39% due to overfitting
#
# **Architecture:**
# 1. Data augmentation (inside model, training-only)
# 2. MobileNetV2 backbone (frozen initially)
# 3. GlobalAveragePooling → BatchNorm → Dense(256) → Dropout → Dense(64 classes)

# %%
from tensorflow.keras import layers, models, Input
from tensorflow.keras.applications import MobileNetV2

# -- Augmentation block (applied only during training) --
augment = tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.1),
], name='augmentation')

# -- Pretrained backbone --
base = MobileNetV2(input_shape=(224,224,3), include_top=False, weights='imagenet')
base.trainable = False   # freeze for phase 1

# -- Full model --
inputs  = Input(shape=(224,224,3))
x       = augment(inputs)
x       = tf.keras.applications.mobilenet_v2.preprocess_input(x)  # single normalisation
x       = base(x, training=False)
x       = layers.GlobalAveragePooling2D()(x)
x       = layers.BatchNormalization()(x)
x       = layers.Dense(256, activation='relu')(x)
x       = layers.Dropout(0.4)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)   # ← num_classes, NOT hardcoded 64

model = models.Model(inputs, outputs)
model.summary(line_length=80)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ augmentation (Sequential)         │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)          │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ subtract (Subtract)               │ (None, 224, 224, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224 (Functional) │ (None, 7, 7, 1280)       │     2,257,984 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 1280)             │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ batch_normalization               │ (None, 1280)             │         5,120 │
# │ (BatchNormalization)              │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 256)              │       327,936 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout (Dropout)                 │ (None, 256)              │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 64)               │        16,448 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 2,607,488 (9.95 MB)
#  Trainable params: 346,944 (1.32 MB)
#  Non-trainable params: 2,260,544 (8.62 MB)

# %% [markdown]
# ## 5. Phase 1 — Train Head (Base Frozen, 15 epochs)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy', patience=5,
        restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, verbose=1),
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history1 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=15, callbacks=callbacks
)
# Out:
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 50s 86ms/step - accuracy: 0.3713 - loss: 2.6217 - val_accuracy: 0.5615 - val_loss: 1.6489 - learning_rate: 0.0010
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 76ms/step - accuracy: 0.5104 - loss: 1.8592 - val_accuracy: 0.5864 - val_loss: 1.5137 - learning_rate: 0.0010
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.5495 - loss: 1.6547 - val_accuracy: 0.6054 - val_loss: 1.4547 - learning_rate: 0.0010
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.5799 - loss: 1.5359 - val_accuracy: 0.6178 - val_loss: 1.4267 - learning_rate: 0.0010
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6011 - loss: 1.4400 - val_accuracy: 0.6200 - val_loss: 1.4202 - learning_rate: 0.0010
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.6086 - loss: 1.3842 - val_accuracy: 0.6236 - val_loss: 1.4139 - learning_rate: 0.0010
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6267 - loss: 1.3347 - val_accuracy: 0.6283 - val_loss: 1.3982 - learning_rate: 0.0010
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6400 - loss: 1.2739 - val_accuracy: 0.6393 - val_loss: 1.3987 - learning_rate: 0.0010
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6417 - loss: 1.2420 - val_accuracy: 0.6371 - val_loss: 1.4125 - learning_rate: 0.0010
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6518 - loss: 1.2153
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - accuracy: 0.6559 - loss: 1.2026 - val_accuracy: 0.6435 - val_loss: 1.4181 - learning_rate: 0.0010
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 77ms/step - accuracy: 0.6870 - loss: 1.0842 - val_accuracy: 0.6589 - val_loss: 1.3504 - learning_rate: 5.0000e-04
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 36s 79ms/step - accuracy: 0.6978 - loss: 1.0327 - val_accuracy: 0.6658 - val_loss: 1.3311 - learning_rate: 5.0000e-04
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 40s 77ms/step - accuracy: 0.7014 - loss: 1.0064 - val_accuracy: 0.6617 - val_loss: 1.3443 - learning_rate: 5.0000e-04
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 35s 78ms/step - accuracy: 0.7094 - loss: 0.9852 - val_accuracy: 0.6683 - val_loss: 1.3296 - learning_rate: 5.0000e-04
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - accuracy: 0.7187 - loss: 0.9528 - val_accuracy: 0.6664 - val_loss: 1.3392 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 14.

# %% [markdown]
# ## 6. Phase 2 — Fine-tune Top Layers (Low LR, 20 epochs)

# %%
# Unfreeze top 40 layers of MobileNetV2
base.trainable = True
for layer in base.layers[:-40]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=20, callbacks=callbacks
)
# Out:
# Epoch 1/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 60s 109ms/step - accuracy: 0.6242 - loss: 1.3453 - val_accuracy: 0.6264 - val_loss: 1.5817 - learning_rate: 1.0000e-04
# Epoch 2/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 80s 106ms/step - accuracy: 0.6799 - loss: 1.1050 - val_accuracy: 0.6311 - val_loss: 1.5305 - learning_rate: 1.0000e-04
# Epoch 3/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7095 - loss: 0.9854
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 108ms/step - accuracy: 0.7083 - loss: 0.9806 - val_accuracy: 0.6396 - val_loss: 1.5476 - learning_rate: 1.0000e-04
# Epoch 4/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 81s 106ms/step - accuracy: 0.7446 - loss: 0.8372 - val_accuracy: 0.6733 - val_loss: 1.3373 - learning_rate: 5.0000e-05
# Epoch 5/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 82s 107ms/step - accuracy: 0.7683 - loss: 0.7601 - val_accuracy: 0.6887 - val_loss: 1.2878 - learning_rate: 5.0000e-05
# Epoch 6/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.7824 - loss: 0.7214 - val_accuracy: 0.6890 - val_loss: 1.2688 - learning_rate: 5.0000e-05
# Epoch 7/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 105ms/step - accuracy: 0.7987 - loss: 0.6561 - val_accuracy: 0.6970 - val_loss: 1.2511 - learning_rate: 5.0000e-05
# Epoch 8/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 105ms/step - accuracy: 0.7988 - loss: 0.6528 - val_accuracy: 0.6990 - val_loss: 1.2422 - learning_rate: 5.0000e-05
# Epoch 9/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 107ms/step - accuracy: 0.8106 - loss: 0.6138 - val_accuracy: 0.7152 - val_loss: 1.2420 - learning_rate: 5.0000e-05
# Epoch 10/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 82s 106ms/step - accuracy: 0.8226 - loss: 0.5651 - val_accuracy: 0.7155 - val_loss: 1.2292 - learning_rate: 5.0000e-05
# Epoch 11/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 47s 104ms/step - accuracy: 0.8254 - loss: 0.5583 - val_accuracy: 0.7114 - val_loss: 1.2204 - learning_rate: 5.0000e-05
# Epoch 12/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.8365 - loss: 0.5216 - val_accuracy: 0.7136 - val_loss: 1.2410 - learning_rate: 5.0000e-05
# Epoch 13/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 106ms/step - accuracy: 0.8427 - loss: 0.4930 - val_accuracy: 0.7158 - val_loss: 1.2253 - learning_rate: 5.0000e-05
# Epoch 14/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8490 - loss: 0.4915
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 105ms/step - accuracy: 0.8495 - loss: 0.4856 - val_accuracy: 0.7163 - val_loss: 1.2441 - learning_rate: 5.0000e-05
# Epoch 15/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 105ms/step - accuracy: 0.8598 - loss: 0.4465 - val_accuracy: 0.7202 - val_loss: 1.1994 - learning_rate: 2.5000e-05
# Epoch 16/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 48s 106ms/step - accuracy: 0.8660 - loss: 0.4159 - val_accuracy: 0.7326 - val_loss: 1.1818 - learning_rate: 2.5000e-05
# Epoch 17/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.8700 - loss: 0.4070 - val_accuracy: 0.7296 - val_loss: 1.2096 - learning_rate: 2.5000e-05
# Epoch 18/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 81s 106ms/step - accuracy: 0.8793 - loss: 0.3835 - val_accuracy: 0.7348 - val_loss: 1.1854 - learning_rate: 2.5000e-05
# Epoch 19/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8768 - loss: 0.3881
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 82s 106ms/step - accuracy: 0.8794 - loss: 0.3763 - val_accuracy: 0.7370 - val_loss: 1.1884 - learning_rate: 2.5000e-05
# Epoch 20/20
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.8854 - loss: 0.3571 - val_accuracy: 0.7403 - val_loss: 1.1845 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 7. Evaluation

# %%
loss, acc = model.evaluate(val_ds)
print(f'\n Validation Accuracy: {acc*100:.1f}%')
print(f'   Validation Loss:     {loss:.4f}')
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.7403 - loss: 1.1845
#
#  Validation Accuracy: 74.0%
#    Validation Loss:     1.1845

# %% [markdown]
# ## 8. Training Curves

# %%
def concat_hist(h1, h2, key):
    return h1.history[key] + h2.history[key]

acc_tr  = concat_hist(history1, history2, 'accuracy')
acc_val = concat_hist(history1, history2, 'val_accuracy')
loss_tr = concat_hist(history1, history2, 'loss')
loss_val= concat_hist(history1, history2, 'val_loss')
split   = len(history1.history['accuracy'])
ep      = range(len(acc_tr))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for ax, tr, vl, title in zip(axes,
    [acc_tr, loss_tr], [acc_val, loss_val],
    ['Accuracy', 'Loss']):
    ax.plot(ep, tr,  label='Train')
    ax.plot(ep, vl,  label='Val')
    ax.axvline(split, color='gray', linestyle='--', label='Fine-tune start')
    ax.set_title(title); ax.legend(); ax.set_xlabel('Epoch')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 9. Save Model

# %%
model.save('food_classifier.keras')
print('Model saved as food_classifier.keras')
# Out:
# Model saved as food_classifier.keras

# %% [markdown]
# ## 10. Predict Image → Class + Nutrition Info
#
# This is where the **two files connect**: the CNN predicts the food class from the image, then we look up its nutrition from the CSV.

# %%
import numpy as np
from PIL import Image as PILImage

def predict_with_nutrition(image_path, top_k=3):
    """
    Given an image path:
    1. CNN predicts the food class
    2. Nutrition lookup from CSV returns calories/protein/fat/carb
    """
    # -- Load & preprocess image --
    img = PILImage.open(image_path).convert('RGB').resize((224, 224))
    arr = np.array(img)[np.newaxis, ...].astype('float32')

    # -- Predict --
    preds  = model.predict(arr, verbose=0)[0]
    top_idx = preds.argsort()[-top_k:][::-1]

    print(f'\n📸 Image: {image_path}')
    print('─' * 50)

    for rank, idx in enumerate(top_idx, 1):
        cls   = class_names[idx]
        conf  = preds[idx] * 100
        nutr  = get_nutrition(cls)

        print(f'  #{rank} {cls.upper():20s}  ({conf:.1f}% confidence)')
        if nutr['calories'] is not None:
            print(f'      Nutrition per 100g:')
            print(f'        Calories : {nutr["calories"]:.1f} kcal')
            print(f'         Protein  : {nutr["protein"]:.1f} g')
            print(f'         Fat      : {nutr["fat"]:.1f} g')
            print(f'         Carbs    : {nutr["carb"]:.1f} g')
        else:
            print(f'       No nutrition data available for this class')
        print()

    # Return top prediction
    best_cls  = class_names[top_idx[0]]
    best_conf = preds[top_idx[0]] * 100
    best_nutr = get_nutrition(best_cls)
    return {'class': best_cls, 'confidence': best_conf, 'nutrition': best_nutr}

# ── Example: run on a few validation images ──────────────────
import os, random

# Pick random images from the validation set
random.seed(42)
sample_images = []
for cls in random.sample(class_names, 5):
    cls_dir = os.path.join(DATA_DIR, cls)
    files   = os.listdir(cls_dir)
    if files:
        sample_images.append((os.path.join(cls_dir, random.choice(files)), cls))

for img_path, true_cls in sample_images:
    print(f'[True label: {true_cls}]')
    result = predict_with_nutrition(img_path)
    correct = '✅' if result['class'] == true_cls else '❌'
    print(f'  → Prediction: {correct}')
    print()
# Out:
# [True label: chips]
#
# 📸 Image: dataset/dataset/chips/chips_56.jpg
# ──────────────────────────────────────────────────
#   #1 CHIPS                 (67.5% confidence)
#       Nutrition per 100g:
#         Calories : 469.0 kcal
#          Protein  : 0.0 g
#          Fat      : 0.0 g
#          Carbs    : 93.3 g
#
#   #2 MILK                  (32.3% confidence)
#       Nutrition per 100g:
#         Calories : 40.0 kcal
#          Protein  : 0.7 g
#          Fat      : 2.3 g
#          Carbs    : 5.4 g
#
#   #3 BURRITO               (0.1% confidence)
#       Nutrition per 100g:
#         Calories : 239.0 kcal
#          Protein  : 9.4 g
#          Fat      : 4.1 g
#          Carbs    : 32.9 g
#
#   → Prediction: ✅
#
# [True label: beef]
#
# 📸 Image: dataset/dataset/beef/beef_73.jpg
# ──────────────────────────────────────────────────
#   #1 BEEF                  (98.6% confidence)
#       Nutrition per 100g:
#         Calories : 156.0 kcal
#          Protein  : 20.0 g
#          Fat      : 5.9 g
#          Carbs    : 0.0 g
#
#   #2 FALAFEL               (0.6% confidence)
#       Nutrition per 100g:
#         Calories : 350.0 kcal
#          Protein  : 8.3 g
#          Fat      : 41.2 g
#          Carbs    : 29.0 g
#
#   #3 KEBAB                 (0.5% confidence)
#       Nutrition per 100g:
#         Calories : 158.0 kcal
#          Protein  : 14.3 g
#          Fat      : 14.3 g
#          Carbs    : 57.1 g
#
#   → Prediction: ✅
#
# [True label: milk]
#
# 📸 Image: dataset/dataset/milk/milk_248.jpg
# ──────────────────────────────────────────────────
#   #1 MILK                  (48.1% confidence)
#       Nutrition per 100g:
#         Calories : 40.0 kcal
#          Protein  : 0.7 g
#          Fat      : 2.3 g
#          Carbs    : 5.4 g
#
#   #2 SWEET_POTATO          (17.2% confidence)
#       Nutrition per 100g:
#         Calories : 116.0 kcal
#          Protein  : 5.5 g
#          Fat      : 1.3 g
#          Carbs    : 16.4 g
#
#   #3 FRIED_CHICKEN         (8.0% confidence)
#       Nutrition per 100g:
#         Calories : 166.0 kcal
#          Protein  : 21.4 g
#          Fat      : 1.8 g
#          Carbs    : 0.0 g
#
#   → Prediction: ✅
#
# [True label: lamb]
#
# 📸 Image: dataset/dataset/lamb/lamb_103.jpg
# ──────────────────────────────────────────────────
#   #1 LAMB                  (100.0% confidence)
#       Nutrition per 100g:
#         Calories : 117.0 kcal
#          Protein  : 17.0 g
#          Fat      : 20.5 g
#          Carbs    : 0.0 g
#
#   #2 CHICKEN               (0.0% confidence)
#       Nutrition per 100g:
#         Calories : 166.0 kcal
#          Protein  : 21.4 g
#          Fat      : 1.8 g
#          Carbs    : 0.0 g
#
#   #3 DUCK                  (0.0% confidence)
#       Nutrition per 100g:
#         Calories : 227.0 kcal
#          Protein  : 18.9 g
#          Fat      : 28.2 g
#          Carbs    : 0.0 g
#
#   → Prediction: ✅
#
# [True label: ice_cream]
#
# 📸 Image: dataset/dataset/ice_cream/ice_cream_9.jpg
# ──────────────────────────────────────────────────
#   #1 ICE_CREAM             (100.0% confidence)
#       Nutrition per 100g:
#         Calories : 299.0 kcal
#          Protein  : 3.0 g
#          Fat      : 12.7 g
#          Carbs    : 39.3 g
#
#   #2 POPCORN               (0.0% confidence)
#       Nutrition per 100g:
#         Calories : 442.0 kcal
#          Protein  : 0.8 g
#          Fat      : 0.0 g
#          Carbs    : 12.8 g
#
#   #3 BURRITO               (0.0% confidence)
#       Nutrition per 100g:
#         Calories : 239.0 kcal
#          Protein  : 9.4 g
#          Fat      : 4.1 g
#          Carbs    : 32.9 g
#
#   → Prediction: ✅

# %% [markdown]
# ## 11. Visual Prediction Grid with Nutrition

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

random.seed(7)
vis_samples = []
for cls in random.sample(class_names, 6):
    cls_dir = os.path.join(DATA_DIR, cls)
    files = [f for f in os.listdir(cls_dir) if f.lower().endswith(('.jpg','.jpeg','.png'))]
    if files:
        vis_samples.append((os.path.join(cls_dir, random.choice(files)), cls))

for ax, (img_path, true_cls) in zip(axes, vis_samples):
    img = PILImage.open(img_path).convert('RGB').resize((224,224))
    arr = np.array(img)[np.newaxis,...].astype('float32')
    preds = model.predict(arr, verbose=0)[0]
    pred_cls = class_names[preds.argmax()]
    conf     = preds.max() * 100
    nutr     = get_nutrition(pred_cls)

    ax.imshow(img)
    color = 'green' if pred_cls == true_cls else 'red'
    title = f'Pred: {pred_cls} ({conf:.0f}%)\nTrue: {true_cls}'
    if nutr['calories']:
        title += f'\n{nutr["calories"]:.0f} kcal | {nutr["protein"]:.1f}g P'
    ax.set_title(title, color=color, fontsize=9)
    ax.axis('off')

plt.suptitle('Food Classifier + Nutrition Lookup', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# chatbot

# %%
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
import io, re
from PIL import Image as PILImage
import numpy as np

# ─────────────────────────────────────────────
# 🔹 STATE
# ─────────────────────────────────────────────
_state = {
    "best_cls":  None,
    "best_conf": None,
    "top_preds": None,
    "nutr":      None,
}

# ─────────────────────────────────────────────
# 🔹 NUTRITION LOOKUP (uses notebook's nutrition_by_key + ALIASES)
# ─────────────────────────────────────────────
def _lookup_nutr(cls):
    key = cls.lower().replace(' ', '_')
    if key in nutrition_by_key:
        return nutrition_by_key[key]
    # Try ALIASES
    alias = ALIASES.get(key, '')
    alias_key = alias.lower().replace(' ', '_')
    if alias_key and alias_key in nutrition_by_key:
        return nutrition_by_key[alias_key]
    # Partial match fallback
    for k in nutrition_by_key:
        if key in k or k in key:
            return nutrition_by_key[k]
    return {}


# ─────────────────────────────────────────────
# 🔹 IMAGE ANALYSIS
# ─────────────────────────────────────────────
def analyse_image(img_bytes, top_k=3):
    img = PILImage.open(io.BytesIO(img_bytes)).convert('RGB').resize((224, 224))
    arr = np.array(img)[np.newaxis, ...].astype('float32')
    preds   = model.predict(arr, verbose=0)[0]
    top_idx = preds.argsort()[-top_k:][::-1]
    top_preds = [(class_names[i], float(preds[i]) * 100) for i in top_idx]
    best_cls  = top_preds[0][0]
    best_conf = top_preds[0][1]
    nutr      = _lookup_nutr(best_cls)   # ✅ direct lookup
    return best_cls, best_conf, top_preds, nutr


# ─────────────────────────────────────────────
# 🔹 BOT LOGIC
# ─────────────────────────────────────────────
def build_bot_reply(user_text, best_cls, best_conf, top_preds, nutr, first=False):
    txt = user_text.lower().strip()

    # ── First message after image upload ──
    if first:
        tops = "\n".join(
            f"  {i+1}. {c.replace('_',' ').title()}  {p:.1f}%"
            for i, (c, p) in enumerate(top_preds)
        )
        nutr_text = ""
        if nutr and nutr.get('calories') is not None:
            nutr_text = (
                f"\n\n🍽 Nutrition per 100g:\n"
                f"  🔥 Calories : {nutr['calories']:.0f} kcal\n"
                f"  💪 Protein  : {nutr['protein']:.1f} g\n"
                f"  🧈 Fat      : {nutr['fat']:.1f} g\n"
                f"  🍞 Carbs    : {nutr['carb']:.1f} g"
            )
        return (
            f"📸 Image analysed!\n\n"
            f"🏆 Top predictions:\n{tops}\n\n"
            f"✅ Best guess: <b>{best_cls.replace('_',' ').title()}</b> ({best_conf:.1f}%)"
            f"{nutr_text}\n\n"
            f"💬 Ask me anything about this food!"
        )

    # ── No image uploaded yet — general food chat ──
    if best_cls is None:
        if any(w in txt for w in ['cal', 'calori', 'كالوري', 'سعر', 'حرار', 'kcal']):
            return "🔥 Calories depend on the food! Upload an image and I'll tell you exactly."
        if any(w in txt for w in ['protein', 'بروتين']):
            return "💪 Protein varies by food. Upload an image for specific info!"
        if any(w in txt for w in ['fat', 'دهن', 'دهون']):
            return "🧈 Fat content depends on the food. Try uploading an image!"
        if any(w in txt for w in ['carb', 'كارب', 'نشا', 'sugar', 'سكر']):
            return "🍞 Carbs vary a lot! Upload a food image and I'll check for you."
        if any(w in txt for w in ['healthy', 'health', 'رجيم', 'صح', 'مفيد']):
            return "⚖️ Generally: veggies & lean protein = healthy. Fried & sugary = less so! Upload an image for a specific answer."
        if any(w in txt for w in ['hi', 'hello', 'hey', 'مرحبا', 'أهلا', 'هاي']):
            return "👋 Hi! I'm your food assistant 🍽️ Upload a food image and I'll analyse it for you!"
        if any(w in txt for w in ['thanks', 'thank', 'شكرا', 'تسلم', 'يسلمو']):
            return "😊 You're welcome! Upload a food image anytime."
        if any(w in txt for w in ['pizza','burger','sushi','salad','chicken','rice',
                                   'بيتزا','برجر','سوشي','سلطة','دجاج','أرز']):
            return "😋 Sounds delicious! Upload a photo of it and I'll give you the full nutrition info."
        return "🤖 I'm your food assistant! Upload a food image 📷 and ask me about calories, protein, fat, carbs, or if it's healthy."

    # ── Calories ──
    if any(w in txt for w in ['cal', 'calori', 'كالوري', 'سعر', 'حرار', 'kcal']):
        if nutr and nutr.get('calories') is not None:
            return f"🔥 <b>{best_cls.replace('_',' ').title()}</b> has <b>{nutr['calories']:.0f} kcal</b> per 100g."
        return "No calorie data available for this food."

    # ── Protein ──
    if any(w in txt for w in ['protein', 'بروتين']):
        if nutr and nutr.get('protein') is not None:
            return f"💪 Protein: <b>{nutr['protein']:.1f}g</b> per 100g."
        return "No protein data available."

    # ── Fat ──
    if any(w in txt for w in ['fat', 'دهن', 'دهون']):
        if nutr and nutr.get('fat') is not None:
            return f"🧈 Fat: <b>{nutr['fat']:.1f}g</b> per 100g."
        return "No fat data available."

    # ── Carbs ──
    if any(w in txt for w in ['carb', 'كارب', 'نشا', 'sugar', 'سكر']):
        if nutr and nutr.get('carb') is not None:
            return f"🍞 Carbs: <b>{nutr['carb']:.1f}g</b> per 100g."
        return "No carbs data available."

    # ── Full nutrition ──
    if any(w in txt for w in ['nutrition', 'all', 'كل', 'كامل', 'summary', 'تغذي', 'قيمة']):
        if nutr and nutr.get('calories') is not None:
            return (
                f"📊 <b>{best_cls.replace('_',' ').title()}</b> per 100g:<br>"
                f"🔥 {nutr['calories']:.0f} kcal &nbsp;|&nbsp; "
                f"💪 {nutr['protein']:.1f}g protein &nbsp;|&nbsp; "
                f"🧈 {nutr['fat']:.1f}g fat &nbsp;|&nbsp; "
                f"🍞 {nutr['carb']:.1f}g carbs"
            )
        return "No nutrition data available."

    # ── Confidence ──
    if any(w in txt for w in ['confidence', 'confident', 'sure', 'نسبة', 'متأكد', 'مؤكد', 'percent']):
        return f"🎯 I'm <b>{best_conf:.1f}%</b> confident this is <b>{best_cls.replace('_',' ').title()}</b>."

    # ── Other predictions ──
    if any(w in txt for w in ['other', 'else', 'alternative', 'second', 'تاني', 'بديل', 'احتمال']):
        others = "<br>".join(
            f"  {i+2}. {c.replace('_',' ').title()} — {p:.1f}%"
            for i, (c, p) in enumerate(top_preds[1:])
        )
        return f"🔍 Other possibilities:<br>{others}"

    # ── Healthy ──
    if any(w in txt for w in ['healthy', 'health', 'good', 'bad', 'diet', 'رجيم', 'صح', 'مفيد']):
        if nutr and nutr.get('calories') is not None:
            cal = nutr['calories']
            tag = ("🟢 low-calorie — great choice!" if cal < 150
                   else "🟡 moderate — okay in portions." if cal < 300
                   else "🔴 high-calorie — enjoy in moderation.")
            return (
                f"⚖️ <b>{best_cls.replace('_',' ').title()}</b> is {tag}<br>"
                f"{cal:.0f} kcal | {nutr['protein']:.1f}g protein | "
                f"{nutr['fat']:.1f}g fat | {nutr['carb']:.1f}g carbs"
            )
        return "Not enough data to assess healthiness."

    # ── What is this ──
    if any(w in txt for w in ['what', 'ايه', 'إيه', 'identify', 'food', 'اكل', 'ده']):
        return f"🍽️ This looks like <b>{best_cls.replace('_',' ').title()}</b> ({best_conf:.1f}% confidence)."

    # ── Greetings ──
    if any(w in txt for w in ['hi', 'hello', 'hey', 'مرحبا', 'أهلا', 'هاي']):
        return f"👋 Hi! I detected <b>{best_cls.replace('_',' ').title()}</b>. What would you like to know?"

    # ── Thanks ──
    if any(w in txt for w in ['thanks', 'thank', 'شكرا', 'تسلم', 'يسلمو']):
        return "😊 You're welcome! Upload another image anytime."

    # ── Fallback ──
    return (
        f"🤔 I can answer about:<br>"
        f"• Calories / Protein / Fat / Carbs<br>"
        f"• Full nutrition summary<br>"
        f"• How confident I am<br>"
        f"• Other predictions<br>"
        f"• Is it healthy?<br><br>"
        f"(Detected: <b>{best_cls.replace('_',' ').title()}</b>)"
    )


# ─────────────────────────────────────────────
# 🔹 CHAT RENDER
# ─────────────────────────────────────────────
def show_msg(msg, who="bot"):
    bg    = "#e8f5e9" if who == "bot" else "#e3f2fd"
    align = "left"    if who == "bot" else "right"
    icon  = "🤖"       if who == "bot" else "🧑"
    msg_html = msg.replace('\n', '<br>')
    with chat_out:
        display(HTML(f"""
        <div style="text-align:{align}; margin:5px 2px;">
          <span style="font-size:1.05em">{icon}</span>
          <span style="
            display:inline-block; max-width:80%; padding:9px 13px;
            background:{bg}; border-radius:12px;
            font-size:0.91em; color:#111; text-align:left;
            font-family:'Segoe UI',sans-serif;
            box-shadow:0 1px 3px rgba(0,0,0,.07);
          ">{msg_html}</span>
        </div>
        """))


# ─────────────────────────────────────────────
# 🔹 WIDGETS
# ─────────────────────────────────────────────
upload_btn = widgets.FileUpload(
    accept='image/*', multiple=False,
    description='📷 Upload Image',
    layout=widgets.Layout(width='180px')
)

text_input = widgets.Text(
    placeholder='Ask something about food...',
    layout=widgets.Layout(width='72%', height='36px')
)

send_btn = widgets.Button(
    description='Send ➤', button_style='primary',
    layout=widgets.Layout(width='90px', height='36px')
)

clear_btn = widgets.Button(
    description='🗑 Clear', button_style='warning',
    layout=widgets.Layout(width='80px', height='36px')
)

chat_out = widgets.Output(layout=widgets.Layout(
    border='1px solid #ddd',
    min_height='300px', max_height='420px',
    overflow_y='auto', padding='10px',
))

img_out = widgets.Output(layout=widgets.Layout(
    width='200px', min_height='50px'
))

status_lbl = widgets.HTML(
    value='<span style="color:gray;font-size:.85em">No image uploaded yet.</span>'
)


# ─────────────────────────────────────────────
# 🔹 EVENTS
# ─────────────────────────────────────────────
def on_upload(change):
    if not upload_btn.value:
        return
    fname     = list(upload_btn.value.keys())[0]
    img_bytes = bytes(upload_btn.value[fname]['content'])

    with img_out:
        clear_output(wait=True)
        display(PILImage.open(io.BytesIO(img_bytes)).resize((190, 190)))

    status_lbl.value = f'<span style="color:green;font-size:.85em">✅ Loaded: {fname}</span>'

    best_cls, best_conf, top_preds, nutr = analyse_image(img_bytes)
    _state.update(best_cls=best_cls, best_conf=best_conf,
                  top_preds=top_preds, nutr=nutr)

    show_msg(build_bot_reply('', best_cls, best_conf, top_preds, nutr, first=True), 'bot')


def on_send(_=None):
    user_text = text_input.value.strip()
    if not user_text:
        return
    text_input.value = ''
    show_msg(user_text, 'user')
    reply = build_bot_reply(
        user_text,
        _state['best_cls'], _state['best_conf'],
        _state['top_preds'], _state['nutr']
    )
    show_msg(reply, 'bot')


def on_clear(_):
    with chat_out:
        clear_output()
    with img_out:
        clear_output()
    _state.update(best_cls=None, best_conf=None, top_preds=None, nutr=None)
    status_lbl.value = '<span style="color:gray;font-size:.85em">No image uploaded yet.</span>'
    show_msg("👋 Hi! I'm your food assistant 🍽️<br>Upload a food image 📷 or ask me a general food question!", "bot")


upload_btn.observe(on_upload, names='value')
send_btn.on_click(on_send)
clear_btn.on_click(on_clear)
text_input.on_submit(on_send)   # ✅ Enter key sends

# ── Greeting on load ──
show_msg("👋 Hi! I'm your food assistant 🍽️<br>Upload a food image 📷 or ask me a general food question!", "bot")


# ─────────────────────────────────────────────
# 🔹 LAYOUT
# ─────────────────────────────────────────────
title = widgets.HTML("""
<div style="
  background:linear-gradient(135deg,#1b5e20,#43a047);
  color:white; padding:13px 18px; border-radius:10px; margin-bottom:8px;
  font-family:'Segoe UI',sans-serif;
">
  <h2 style="margin:0;font-size:1.3em;">🍽️ Food Chatbot</h2>
  <p style="margin:3px 0 0;font-size:.8em;opacity:.9;">
    Ask general food questions or upload an image for nutrition analysis!
  </p>
</div>
""")

left  = widgets.VBox([chat_out,
                      widgets.HBox([text_input, send_btn, clear_btn])],
                     layout=widgets.Layout(width='65%'))

right = widgets.VBox([
    widgets.HTML('<b style="font-family:Segoe UI;font-size:.88em">📷 Image preview</b>'),
    img_out,
    upload_btn,
    status_lbl
], layout=widgets.Layout(width='33%', padding='0 0 0 12px'))

display(title, widgets.HBox([left, right]))
# Out:
# HTML(value='\n<div style="\n  background:linear-gradient(135deg,#1b5e20,#43a047);\n  color:white; padding:13px…
# HBox(children=(VBox(children=(Output(layout=Layout(border='1px solid #ddd', max_height='420px', min_height='30…

# %% [markdown]
# f1-score

# %%
from sklearn.metrics import f1_score
import numpy as np
import tensorflow as tf # Import tensorflow to load the model

# Reload the Keras model
model = tf.keras.models.load_model('food_classifier.keras')

# Extract true labels from val_ds
y_true = []
for images, labels in val_ds:
    y_true.extend(labels.numpy())
y_true = np.array(y_true)

# Get predictions from the model on val_ds
predictions = model.predict(val_ds)
y_pred = np.argmax(predictions, axis=1)

# Calculate F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print("F1 Score (weighted):", f1)
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step
# F1 Score (weighted): 0.742119919518706

# %% [markdown]
# confusion matrix

# %%
sns.heatmap(cm, annot=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,10))
sns.heatmap(cm, cmap="Blues")
plt.show()

# %%
from torchvision import models

model = models.mobilenet_v2(pretrained=True)
model.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 68.6MB/s]
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %%
# !wget https://download.pytorch.org/models/mobilenet_v2-b0353104.pth -O mobilenet_v2.pth
# Out:
# --2026-05-13 02:44:14--  https://download.pytorch.org/models/mobilenet_v2-b0353104.pth
# Resolving download.pytorch.org (download.pytorch.org)... 99.84.215.59, 99.84.215.89, 99.84.215.76, ...
# Connecting to download.pytorch.org (download.pytorch.org)|99.84.215.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14212972 (14M) [binary/octet-stream]
# Saving to: ‘mobilenet_v2.pth’
#
# mobilenet_v2.pth    100%[===================>]  13.55M  --.-KB/s    in 0.09s
#
# 2026-05-13 02:44:14 (146 MB/s) - ‘mobilenet_v2.pth’ saved [14212972/14212972]
